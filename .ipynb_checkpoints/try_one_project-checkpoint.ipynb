# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\bisun\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import re, string

# %%
df= pd.read_csv('data_for_project.csv', encoding = 'ISO-8859-1')

# %%
df.sample(5)
# Out:
#                                                    Text  Score
# 2051                                          Prasansha    1.0
# 1702      Vyaktigat swatantrata ko mahatwa samjhe chhan    1.0
# 4697                               paadhn ni ddr laagyo    0.0
# 2807  uniihruuko laagi ssto ttyaablett pryog grn r s...    1.0
# 4711      ds ruupaiyaa bhet jojo caaucaau po khaainthyo    1.0

# %%
df
# Out:
#                             Text  Score
# 0              sanchai ho timi ?    1.0
# 1               tmro k xa khabr?    1.0
# 2             naya naulo sunau ?    1.0
# 3             mero ni thikai xa.    1.0
# 4       zindagi ramailo nai xa .    1.0
# ...                          ...    ...
# 4953                bncro haancn    1.0
# 4954         khuttttaa maa bncro    0.0
# 4955      dherai harami manxe ho    0.0
# 4956  harami kaa garera basxa yo    0.0
# 4957      ek number harami xa yo    0.0
#
# [4958 rows x 2 columns]

# %%
df.duplicated().sum()
# Out:
# 563

# %%
df.isnull().sum()
# Out:
# Text     0
# Score    3
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df = df.drop_duplicates(keep='first')

# %%
df
# Out:
#                             Text  Score
# 0              sanchai ho timi ?    1.0
# 1               tmro k xa khabr?    1.0
# 2             naya naulo sunau ?    1.0
# 3             mero ni thikai xa.    1.0
# 4       zindagi ramailo nai xa .    1.0
# ...                          ...    ...
# 4953                bncro haancn    1.0
# 4954         khuttttaa maa bncro    0.0
# 4955      dherai harami manxe ho    0.0
# 4956  harami kaa garera basxa yo    0.0
# 4957      ek number harami xa yo    0.0
#
# [4392 rows x 2 columns]

# %%
df['Score'].value_counts()
# Out:
# 1.0    2721
# 0.0    1671
# Name: Score, dtype: int64

# %%
df
# Out:
#                             Text  Score
# 0              sanchai ho timi ?    1.0
# 1               tmro k xa khabr?    1.0
# 2             naya naulo sunau ?    1.0
# 3             mero ni thikai xa.    1.0
# 4       zindagi ramailo nai xa .    1.0
# ...                          ...    ...
# 4953                bncro haancn    1.0
# 4954         khuttttaa maa bncro    0.0
# 4955      dherai harami manxe ho    0.0
# 4956  harami kaa garera basxa yo    0.0
# 4957      ek number harami xa yo    0.0
#
# [4392 rows x 2 columns]

# %%
plt.pie(df['Score'].value_counts(), labels=['Positive', 'Negative'], autopct='%0.2f')
plt.show()

# %%
#df['num_characters'] = df['Text'].apply(len)
#df['num_words'] = df['Text'].apply(lambda x: len(nltk.word_tokenize(x)))
#df['num_sentences'] = df['Text'].apply(lambda x: len(nltk.sent_tokenize(x)))

# %%
#plt.figure(figsize = (12,6))
#sns.histplot(df[df['Score']==0]['num_characters'] , color='red')
#sns.histplot(df[df['Score']==1]['num_characters'] ,color='green')

# %%
#plt.figure(figsize = (12,6))
#sns.histplot(df[df['Score']==0]['num_words'] , color='red')
#sns.histplot(df[df['Score']==1]['num_words'] ,color='green')

# %%
#df = df.drop(['num_words','num_sentences','num_characters'] ,axis=1)

# %%
df
# Out:
#                             Text  Score
# 0              sanchai ho timi ?    1.0
# 1               tmro k xa khabr?    1.0
# 2             naya naulo sunau ?    1.0
# 3             mero ni thikai xa.    1.0
# 4       zindagi ramailo nai xa .    1.0
# ...                          ...    ...
# 4953                bncro haancn    1.0
# 4954         khuttttaa maa bncro    0.0
# 4955      dherai harami manxe ho    0.0
# 4956  harami kaa garera basxa yo    0.0
# 4957      ek number harami xa yo    0.0
#
# [4392 rows x 2 columns]

# %%
custom_stopwords = ['ek','hai','tyo','nai','k', 'ko', 'ma', 'la','lai', 'le', 'ka', 'ko', 'ho','ehh','hmm','ha','hajur','ta','haha' , 'vayo','timi','tapai','uni','usko','usle','unle','ake','yrr','oh' ,'ohh', 'hun', 'ta', 'ra','po','pani','yesle','ni','hamro','tw','tmle','tmlai','tmele','yo','chhan','xa','pni','chha','timro','timi','maile','ma' ,'honi','hota']

# %%
common_suffixes = ['haru', 'ko','lai','ko','hos','sake','paxi','kheri','ma','hunxa','xu']

# %%
#%%writefile preprocessing.py
custom_stopwords = ['ek','hai','tyo','nai','k', 'ko', 'ma', 'la','lai', 'le', 'ka', 'ko', 'ho','ehh','hmm','ha','hajur','ta','haha' , 'vayo','timi','tapai','uni','usko','usle','unle','ake','yrr','oh' ,'ohh', 'hun', 'ta', 'ra','po','pani','yesle','ni','hamro','tw','tmle','tmlai','tmele','yo','chhan','xa','pni','chha','timro','timi','maile','ma' ,'honi','hota']

def clean_sent(sent):
    #if isinstance(sent, str):
        # If a single text input is provided, convert it to a list
        #sent = [sent]
    words = nltk.word_tokenize(sent)
    
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    words = [re_punc.sub('' ,word) for word in words]
    
    re_printable = re.compile('[^%s]' %re.escape(string.printable))
    words = [re_printable.sub('',word)for word in words]
    
    words = [word for word in words if word.isalpha()]
    
    words = [word for word in words if len(word)>1]
    
    words = [word.lower() for word in words]
    
    words = [word for word in words if word not in custom_stopwords]
    words = [word[:-4] + 'xa' if word.endswith('chha') else word for word in words]
    words = [word[:-5] + 'xan' if word.endswith('chhan') else word for word in words]
    words = [word[:-5] + 'xau' if word.endswith('chhau') else word for word in words]
    words = [word[:-2] + 'xa' if word.endswith('ch') else word for word in words]
    words = [word[:-5] + 'xaina' if word.endswith('chain') else word for word in words]
    words = [word[:-7] + 'xaina' if word.endswith('chhaina') else word for word in words]
    words = [word[:-6] + 'xaina' if word.endswith('chaina') else word for word in words]
    

 
    
    #words = [wn.lemmatize(word ,pos='v') for word in words]
    
    words = [word[:-4] if (word.endswith('haru') and len(word) > 4) else word for word in words]
    words = [word[:-2] if (word.endswith('ko') and len(word) > 2) else word for word in words]
    words = [word[:-3] if (word.endswith('lai') and len(word) >3) else word for word in words]
    words = [word[:-2] if word.endswith('ko') and len (word)> 2 else word for word in words]
    words = [word[:-4] if word.endswith('hos') and len (word)> 3 else word for word in words]
    words = [word[:-4] if word.endswith('sake')and len (word)> 4 else word for word in words]
    words = [word[:-4] if word.endswith('paxi')and len (word)> 4 else word for word in words]
    words = [word[:-5] if word.endswith('kheri') and len (word)> 5 else word for word in words]
    words = [word[:-2] if word.endswith('ma') and len (word)> 2 else word for word in words]
    words = [word[:-5] if word.endswith('hunxa') and len (word)> 5 else word for word in words]
    words = [word[:-5] if word.endswith('hunxu')and len (word)> 5 else word for word in words]
    words = [word[:-2] if word.endswith('xu')and len (word)> 2 else word for word in words]
    words = [word[:-2] if word.endswith('xa')and len (word)> 2 else word for word in words]
    words = [word[:-4] if word.endswith('vayo')and len (word)> 4 else word for word in words]
    words = [word[:-2] if word.endswith('le')and len (word)> 2 else word for word in words]
    #words =[word[:-len(suffix)] if (word.endswith(suffix) and len(word) > len(suffix)) else word for word in words for suffix in common_suffixes]
    
    words = set(words)
    
    return  " ".join(words)
# Out:
# Writing preprocessing.py

# %%
clean_sent('yaha manxeharu paxi fataha vayakachhan')
# Out:
# 'fataha paxi vayakaxan yaha manxe'

# %%
df['Text'] = df['Text'].apply(clean_sent)
# Out:
# C:\Users\bisun\AppData\Local\Temp/ipykernel_7992/2063979165.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Text'] = df['Text'].apply(clean_sent)

# %%
df
# Out:
#                        Text  Score
# 0                   sanchai    1.0
# 1                tmro khabr    1.0
# 2          naulo sunau naya    1.0
# 3               thikai mero    1.0
# 4           ramailo zindagi    1.0
# ...                     ...    ...
# 4953           haancn bncro    1.0
# 4954    khuttttaa bncro maa    0.0
# 4955    dherai manxe harami    0.0
# 4956  kaa bas garera harami    0.0
# 4957          number harami    0.0
#
# [4392 rows x 2 columns]

# %%
df.duplicated().sum()
# Out:
# 35

# %%
df = df.drop_duplicates(keep='first')

# %%
df
# Out:
#                        Text  Score
# 0                   sanchai    1.0
# 1                tmro khabr    1.0
# 2          naulo sunau naya    1.0
# 3               thikai mero    1.0
# 4           ramailo zindagi    1.0
# ...                     ...    ...
# 4953           haancn bncro    1.0
# 4954    khuttttaa bncro maa    0.0
# 4955    dherai manxe harami    0.0
# 4956  kaa bas garera harami    0.0
# 4957          number harami    0.0
#
# [4357 rows x 2 columns]

# %%
from wordcloud import WordCloud
wc =WordCloud(width=1000 ,height=1000, min_font_size=10, background_color='white')

# %%
pos_wc = wc.generate(df[df['Score'] == 1]['Text'].str.cat(sep=" "))

# %%
pos_wc

# %%
plt.figure(figsize=(10,8))
plt.imshow(pos_wc)

# %%
neg_wc = wc.generate(df[df['Score'] == 0]['Text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(10,8))
plt.imshow(neg_wc)

# %%
pos_corpus = []
for msg in df[df['Score'] ==1]['Text'].tolist():
    for word in msg.split():
        pos_corpus.append(word)

# %%
neg_corpus = []
for msg in df[df['Score'] ==0]['Text'].tolist():
    for word in msg.split():
        neg_corpus.append(word)

# %%
pos_corpus
# Out:
# ['sanchai',
#  'tmro',
#  'khabr',
#  'naulo',
#  'sunau',
#  'naya',
#  'thikai',
#  'mero',
#  'ramailo',
#  'zindagi',
#  'sabai',
#  'ghar',
#  'tmro',
#  'sanchai',
#  'xan',
#  'vane',
#  'thikai',
#  'nasta',
#  'khana',
#  'jam',
#  'na',
#  'sikaihal',
#  'sodhana',
#  'naaya',
#  'saman',
#  'ahi',
#  'mero',
#  'use',
#  'garana',
#  'exercise',
#  'garne',
#  'tmro',
#  'bela',
#  'time',
#  'tmro',
#  'gym',
#  'jane',
#  'hola',
#  'pakaisakyau',
#  'khana',
#  'help',
#  'garna',
#  'aam',
#  'haldi',
#  'hijo',
#  'update',
#  'project',
#  'hisab',
#  'sike',
#  'hijo',
#  'padhnu',
#  'haru',
#  'ramro',
#  'book',
#  'kura',
#  'garnu',
#  'respect',
#  'par',
#  'sir',
#  'laptop',
#  'matrai',
#  'hijo',
#  'naya',
#  'kine',
#  'bare',
#  'kehi',
#  'yes',
#  'dinu',
#  'na',
#  'sikna',
#  'hint',
#  'tyata',
#  'garana',
#  'check',
#  'gardi',
#  'explore',
#  'garna',
#  'lag',
#  'ramro',
#  'kura',
#  'ma',
#  'naya',
#  'ghumna',
#  'rakh',
#  'jane',
#  'chaso',
#  'kura',
#  'badhi',
#  'yetai',
#  'thau',
#  'tira',
#  'dherai',
#  'ghumne',
#  'aauna',
#  'sathi',
#  'question',
#  'sikau',
#  'na',
#  'chinta',
#  'bare',
#  'mero',
#  'khasai',
#  'nagara',
#  'bhaya',
#  'lagi',
#  'tmro',
#  'gardin',
#  'miliha',
#  'kura',
#  'hau',
#  'sathi',
#  'mero',
#  'groupwise',
#  'hun',
#  'banayara',
#  'chitto',
#  'garda',
#  'kaam',
#  'gar',
#  'mero',
#  'afno',
#  'jasari',
#  'kaam',
#  'jau',
#  'sathi',
#  'khana',
#  'khayara',
#  'nasta',
#  'tmro',
#  'bhayo',
#  'bike',
#  'ramro',
#  'enginee',
#  'rahe',
#  'bike',
#  'aaya',
#  'features',
#  'naya',
#  'ghumna',
#  'bike',
#  'aaudaina',
#  'khasai',
#  'jada',
#  'problem',
#  'sanga',
#  'padha',
#  'ramro',
#  'aa',
#  'exam',
#  'sodha',
#  'ma',
#  'naaya',
#  'jasari',
#  'gar',
#  'kaam',
#  'sochera',
#  'gar',
#  'matrai',
#  'bolne',
#  'ahi',
#  'gar',
#  'kura',
#  'sake',
#  'kaam',
#  'rw',
#  'gardisakyau',
#  'help',
#  'gardimla',
#  'hun',
#  'bata',
#  'mero',
#  'sahayog',
#  'tarfa',
#  'khabar',
#  'paxi',
#  'gardin',
#  'di',
#  'paisa',
#  'nagara',
#  'chinta',
#  'paisa',
#  'ahi',
#  'sanga',
#  'gara',
#  'vaihal',
#  'ramro',
#  'tmi',
#  'sakxau',
#  'garna',
#  'kaam',
#  'vane',
#  'rahe',
#  'jastai',
#  'tmro',
#  'khusi',
#  'soch',
#  'bare',
#  'bhan',
#  'yes',
#  'bare',
#  'garxau',
#  'maja',
#  'kaam',
#  'thikai',
#  'zindagi',
#  'chaldai',
#  'mero',
#  'bistarai',
#  'vaihal',
#  'gareni',
#  'hola',
#  'vaisakyo',
#  'aaba',
#  'herana',
#  'pathaidi',
#  'hola',
#  'vaisakyo',
#  'mero',
#  'gare',
#  'asal',
#  'manxe',
#  'thik',
#  'manxe',
#  'bujh',
#  'vaen',
#  'haru',
#  'kura',
#  'keto',
#  'bhan',
#  'haru',
#  'sanga',
#  'ramro',
#  'afno',
#  'kura',
#  'haru',
#  'gar',
#  'kura',
#  'pura',
#  'bhane',
#  'afno',
#  'kura',
#  'lobh',
#  'gardaina',
#  'bujh',
#  'kura',
#  'sabai',
#  'man',
#  'vaen',
#  'vane',
#  'sanga',
#  'sun',
#  'ramro',
#  'bishwash',
#  'yes',
#  'garda',
#  'hun',
#  'manxan',
#  'yes',
#  'sabai',
#  'bishwashilo',
#  'maxne',
#  'vane',
#  'tai',
#  'mi',
#  'kura',
#  'garis',
#  'tai',
#  'sahi',
#  'kura',
#  'keto',
#  'bujh',
#  'hos',
#  'kura',
#  'vane',
#  'man',
#  'jasari',
#  'gar',
#  'safa',
#  'aja',
#  'room',
#  'garixas',
#  'sanga',
#  'aayau',
#  'ramrai',
#  'hola',
#  'saji',
#  'thiyo',
#  'padhai',
#  'chaldai',
#  'ramrai',
#  'tmro',
#  'college',
#  'ramro',
#  'vaen',
#  'mil',
#  'pheri',
#  'kura',
#  'jahi',
#  'xu',
#  'tmro',
#  'kura',
#  'sahamat',
#  'paryo',
#  'hunu',
#  'sahamat',
#  'sahamati',
#  'meroni',
#  'tmro',
#  'kura',
#  'aja',
#  'sajilo',
#  'kaam',
#  'bhayo',
#  'sakiyo',
#  'garda',
#  'xito',
#  'garnu',
#  'par',
#  'xito',
#  'dinu',
#  'sakai',
#  'xitai',
#  'par',
#  'garexau',
#  'xitai',
#  'kaam',
#  'thikai',
#  'tmro',
#  'kura',
#  'mankai',
#  'garyau',
#  'kura',
#  'bujhxay',
#  'mankai',
#  'kura',
#  'confidennce',
#  'tmro',
#  'afno',
#  'kura',
#  'sajilo',
#  'yesto',
#  'rahe',
#  'bujhe',
#  'kura',
#  'sajilo',
#  'rahe',
#  'kaam',
#  'bho',
#  'katne',
#  'pali',
#  'saji',
#  'sanga',
#  'choti',
#  'padha',
#  'ramro',
#  'vane',
#  'gara',
#  'majja',
#  'sunne',
#  'gara',
#  'dekhi',
#  'padhne',
#  'pahi',
#  'kaam',
#  'samhal',
#  'gar',
#  'kaam',
#  'kura',
#  'usali',
#  'sake',
#  'sikai',
#  'income',
#  'ramro',
#  'bhayo',
#  'mero',
#  'choti',
#  'vane',
#  'hoina',
#  'rw',
#  'tehi',
#  'sanchai',
#  'paryo',
#  'hunu',
#  'sanchai',
#  'xau',
#  'khabr',
#  'aru',
#  'sodhna',
#  'phone',
#  'matra',
#  'khabr',
#  'gare',
#  'ramailo',
#  'aaja',
#  'ramailo',
#  'garnu',
#  'par',
#  'sakiya',
#  'time',
#  'bhayana',
#  'ramailo',
#  'thaha',
#  'gardai',
#  'pahilo',
#  'din',
#  'garnu',
#  'yeti',
#  'thikai',
#  'thikai',
#  'tmro',
#  'ajkal',
#  'thikai',
#  'tmro',
#  'chaldai',
#  'business',
#  'sangat',
#  'tmro',
#  'thiakai',
#  'sodha',
#  'naauda',
#  'na',
#  'chahi',
#  'sodhera',
#  'sajilo',
#  'sikda',
#  'hun',
#  'sam',
#  'time',
#  'dherai',
#  'sike',
#  'bas',
#  'dimag',
#  'sodhera',
#  'kura',
#  'sodhu',
#  'ramro',
#  'din',
#  'sikai',
#  'us',
#  'sikaya',
#  'vaya',
#  'sikayara',
#  'ramro',
#  'tarika',
#  'sikne',
#  'sanga',
#  'sikdo',
#  'rahe',
#  'ramro',
#  'rahe',
#  'sikne',
#  'sanga',
#  'ramro',
#  'bela',
#  'dhyan',
#  'dido',
#  'vane',
#  'garyau',
#  'afai',
#  'ramro',
#  'garxan',
#  'sabai',
#  'afno',
#  'afai',
#  'kaam',
#  'garnuparyo',
#  'afai',
#  'garda',
#  'afai',
#  'ramro',
#  'va',
#  'gare',
#  'rarmo',
#  'garnu',
#  'project',
#  'dherai',
#  'kaam',
#  'hami',
#  'garnu',
#  'par',
#  'daily',
#  'exercise',
#  'garnu',
#  'exercise',
#  'kura',
#  'ramro',
#  'dherai',
#  'sike',
#  'gaera',
#  'kura',
#  'exercise',
#  'garnu',
#  'par',
#  'project',
#  'sabi',
#  'kaam',
#  'bani',
#  'padhne',
#  'ajkal',
#  'mero',
#  'basisakyo',
#  'hun',
#  'dimag',
#  'bikas',
#  'padhera',
#  'hun',
#  'knowledge',
#  'padhney',
#  'manis',
#  'badhi',
#  'padhisaknu',
#  'tapai',
#  'kai',
#  'kura',
#  'taip',
#  'padhnu',
#  'tapai',
#  'hami',
#  'padhe',
#  'sunuanus',
#  'kura',
#  'tapai',
#  'hami',
#  'padhe',
#  'kura',
#  'sikaunus',
#  'bare',
#  'desh',
#  'ajkal',
#  'chaso',
#  'ma',
#  'badhe',
#  'bare',
#  'tmro',
#  'chaso',
#  'ma',
#  'badhe',
#  'rakhna',
#  'yesto',
#  'chaso',
#  'kura',
#  'thalexau',
#  'jas',
#  'kura',
#  'rakh',
#  'chaso',
#  'pathai',
#  'rw',
#  'patha',
#  'time',
#  'kati',
#  'pathaya',
#  'aaipug',
#  'pharak',
#  'soch',
#  'par',
#  'manxe',
#  'sochera',
#  'bo',
#  'ramro',
#  'dherai',
#  'sakti',
#  'sochne',
#  'mind',
#  'sochne',
#  'hunupar',
#  'bela',
#  'cool',
#  'bani',
#  'basalnu',
#  'par',
#  'garne',
#  'sahayog',
#  'bolau',
#  'bela',
#  'sahayog',
#  'pare',
#  'garna',
#  'ready',
#  'hun',
#  'sahayog',
#  'sadhai',
#  'bani',
#  'mero',
#  'garne',
#  'sahayog',
#  'sathi',
#  'vane',
#  'vaihal',
#  'xitai',
#  'kaam',
#  'vaihal',
#  'kaam',
#  'saja',
#  'van',
#  'vaiha',
#  'vane',
#  'vaisakyo',
#  'khabar',
#  'gar',
#  'garne',
#  'vaya',
#  'khabar',
#  'garna',
#  'sak',
#  'kaam',
#  'kaam',
#  'sakxau',
#  'garna',
#  'tme',
#  'vane',
#  'gardeu',
#  'sakxau',
#  'tme',
#  'sakne',
#  'bela',
#  'sakera',
#  'gara',
#  'khabar',
#  'sab',
#  'hun',
#  'party',
#  'sakisake',
#  'sabali',
#  'khusi',
#  'pal',
#  'simana',
#  'tmro',
#  'khusi',
#  'xaina',
#  'parxau',
#  'khusi',
#  'sabaiali',
#  'khusi',
#  'samaya',
#  'bhan',
#  'bare',
#  'sanga',
#  'yes',
#  'ramro',
#  'garne',
#  'xu',
#  'vane',
#  'jasari',
#  'kaam',
#  'sanga',
#  'asal',
#  'gare',
#  'rahexau',
#  'bani',
#  'tmro',
#  'asal',
#  'bujh',
#  'kura',
#  'keto',
#  'vane',
#  'man',
#  'majja',
#  'sun',
#  'sikau',
#  'bujhera',
#  'hamlaini',
#  'bujhnu',
#  'kura',
#  'par',
#  'matrai',
#  'hun',
#  'yesto',
#  'kura',
#  'bujhe',
#  'sajilo',
#  'mannu',
#  'par',
#  'afu',
#  'thulo',
#  'vane',
#  'vanda',
#  'vanda',
#  'sune',
#  'ramro',
#  'sunnu',
#  'aru',
#  'kura',
#  'par',
#  'aru',
#  'sunera',
#  'react',
#  'matrai',
#  'ramro',
#  'garnupar',
#  'kura',
#  'vane',
#  'sagna',
#  'exam',
#  'ramrai',
#  'aaja',
#  'sanga',
#  'gara',
#  'haita',
#  'ramro',
#  'saman',
#  'rahe',
#  'ramro',
#  'sanga',
#  'garnu',
#  'par',
#  'ramro',
#  'kura',
#  'sanga',
#  'milnu',
#  'par',
#  'ramro',
#  'garxau',
#  'kaam',
#  'milera',
#  'tmro',
#  'mi',
#  'kura',
#  'mero',
#  'milexi',
#  'sajilo',
#  'kura',
#  'hun',
#  'milayara',
#  'kura',
#  'bujhana',
#  'janirakha',
#  'kura',
#  'tme',
#  'sanga',
#  'khusi',
#  'aaja',
#  'ramailo',
#  'zindagi',
#  'mero',
#  'ramro',
#  'mausam',
#  'va',
#  'parera',
#  'ramro',
#  'xu',
#  'vani',
#  'garisaknu',
#  'dai',
#  'tapai',
#  'jana',
#  'vanna',
#  'sabai',
#  'timi',
#  'na',
#  'ali',
#  'aauna',
#  'khana',
#  'aaja',
#  'ramro',
#  'par',
#  'ma',
#  'sarai',
#  'ful',
#  'rahe',
#  'ramro',
#  'ali',
#  'kura',
#  'sarai',
#  'gardin',
#  'halne',
#  'kaam',
#  'ful',
#  'gardimla',
#  'baki',
#  'tmro',
#  'vane',
#  'kaam',
#  'khane',
#  'gara',
#  'dherai',
#  'khana',
#  'banauna',
#  'sikau',
#  'aaja',
#  'aaja',
#  'ramro',
#  'mausam',
#  'manxe',
#  'hau',
#  'ramro',
#  'khushi',
#  'haru',
#  'cha',
#  'sukha',
#  'jeevan',
#  'hsailo',
#  'aadhar',
#  'muhar',
#  'jiban',
#  'umanga',
#  'din',
#  'liera',
#  'harek',
#  'naya',
#  'aao',
#  'sucess',
#  'paila',
#  'sachai',
#  'paaun',
#  'aafno',
#  'harau',
#  'sapana',
#  'garna',
#  'din',
#  'sakxin',
#  'srijana',
#  'harek',
#  'naya',
#  'shakti',
#  'atmavishwas',
#  'jiban',
#  'khushi',
#  'ramaunus',
#  'jindagi',
#  'bhari',
#  'hami',
#  'pheri',
#  'ramailo',
#  'bhetaula',
#  'prerna',
#  'paau',
#  'bata',
#  'dusre',
#  'utsah',
#  'bistarai',
#  'hami',
#  'kina',
#  'hunu',
#  'na',
#  'safal',
#  'imoprtant',
#  'hun',
#  'sangai',
#  'bhaye',
#  'huda',
#  'klo',
#  'manchhe',
#  'badhi',
#  'kadam',
#  'marga',
#  'rakhaula',
#  'pragati',
#  'jaos',
#  'kahi',
#  'hami',
#  'sikaudai',
#  'bujhnuhunxau',
#  'jeevan',
#  'khushi',
#  'saral',
#  'haru',
#  'jivan',
#  'sathai',
#  'chihan',
#  'sabai',
#  'gar',
#  'solve',
#  'kura',
#  'samay',
#  'lag',
#  'sarthakata',
#  'bhayo',
#  'ramailo',
#  'jasto',
#  'deu',
#  'jeevan',
#  'samay',
#  'baki',
#  'samjhauna',
#  'samjhanu',
#  'din',
#  'paaun',
#  'raat',
#  'naya',
#  'andhera',
#  'samjhera',
#  'samjhauta',
#  'prati',
#  'garau',
#  'sukh',
#  'pa',
#  'jeevan',
#  'aaja',
#  'bhari',
#  'din',
#  'kadam',
#  'harek',
#  'rakhaula',
#  'hati',
#  'paau',
#  'bhaye',
#  'asafal',
#  'samadhan',
#  'samjhera',
#  'samay',
#  'ujjwal',
#  'bhavisya',
#  'samjhau',
#  'pahila',
#  'lagi',
#  'samay',
#  'ujjwal',
#  'rahan',
#  'kura',
#  'yad',
#  'jeevan',
#  'sambhavna',
#  'kadammai',
#  'haru',
#  'kadam',
#  'rahan',
#  'ojashwi',
#  'siddhi',
#  'badhi',
#  'din',
#  'haru',
#  'prati',
#  'paaun',
#  'kura',
#  'sikh',
#  'din',
#  'prati',
#  'lekhnuhosh',
#  'garaun',
#  'hastakshar',
#  'lag',
#  'garau',
#  'bhayo',
#  'ramailo',
#  'muskan',
#  'jeevan',
#  'jasto',
#  'garau',
#  'saphalta',
#  'garos',
#  'khada',
#  'aafnai',
#  'agadi',
#  'kaam',
#  'haru',
#  'paaun',
#  'sathai',
#  'sundarta',
#  'jeevan',
#  'khud',
#  'jaba',
#  'sakchhu',
#  'banchhu',
#  'badalna',
#  'badal',
#  'din',
#  'haru',
#  'prati',
#  'paaun',
#  'kura',
#  'naya',
#  'sikh',
#  'dekhn',
#  'garau',
#  'jivan',
#  'chamatkar',
#  'aafno',
#  'uddhar',
#  'pi',
#  'paaun',
#  'nagari',
#  'bas',
#  'purni',
#  'aafnai',
#  'sapana',
#  'khushi',
#  'haru',
#  'sangai',
#  'jeevan',
#  'hos',
#  'bataunu',
#  'bhari',
#  'haru',
#  'purni',
#  'suraj',
#  'jeevan',
#  'ugne',
#  'marga',
#  'pragati',
#  'dekhau',
#  'chal',
#  'saphalta',
#  'samjhera',
#  'haru',
#  'kasta',
#  'paaun',
#  'bhulera',
#  'naya',
#  'purano',
#  ...]

# %%
type(pos_corpus)
# Out:
# list

# %%
neg_corpus
# Out:
# ['garayu',
#  'khatam',
#  'kaam',
#  'hawa',
#  'gar',
#  'lastai',
#  'kaam',
#  'ahi',
#  'hawa',
#  'kura',
#  'aayara',
#  'garyau',
#  'tme',
#  'yesto',
#  'jot',
#  'kura',
#  'nagara',
#  'rai',
#  'hawa',
#  'manxe',
#  'bike',
#  'bigri',
#  'sakyo',
#  'mero',
#  'birse',
#  'hijo',
#  'garna',
#  'kina',
#  'xas',
#  'tai',
#  'suna',
#  'ma',
#  'man',
#  'garxas',
#  'hawa',
#  'mula',
#  'lagyo',
#  'kura',
#  'tehi',
#  'janirakh',
#  'bare',
#  'sanga',
#  'tai',
#  'ramro',
#  'mero',
#  'jad',
#  'raksi',
#  'bani',
#  'khane',
#  'mero',
#  'bani',
#  'padhne',
#  'xaina',
#  'mero',
#  'khasai',
#  'wakka',
#  'thalyo',
#  'lagna',
#  'zindagi',
#  'ma',
#  'dekhi',
#  'bike',
#  'hijo',
#  'bigryo',
#  'pheri',
#  'kehi',
#  'khasai',
#  'kaam',
#  'xaina',
#  'paryo',
#  'bato',
#  'yettikai',
#  'hijo',
#  'jhagada',
#  'thau',
#  'chaldaina',
#  'ali',
#  'mero',
#  'dimag',
#  'thik',
#  'aru',
#  'haru',
#  'sanga',
#  'ghulmil',
#  'hudaina',
#  'khasai',
#  'manxe',
#  'psycho',
#  'ali',
#  'jasto',
#  'chinta',
#  'parihal',
#  'nagar',
#  'thik',
#  'tes',
#  'dinna',
#  'bal',
#  'kura',
#  'tero',
#  'garna',
#  'sa',
#  'bas',
#  'sak',
#  'aaukat',
#  'ramro',
#  'xu',
#  'khasai',
#  'nagar',
#  'gardai',
#  'rahena',
#  'tehi',
#  'lag',
#  'ma',
#  'alxi',
#  'kasai',
#  'aru',
#  'bhanana',
#  'subject',
#  'garo',
#  'hun',
#  'pali',
#  'vain',
#  'hola',
#  'fail',
#  'khasai',
#  'bujhina',
#  'sir',
#  'padhaya',
#  'paryo',
#  'garo',
#  'khai',
#  'ma',
#  'hal',
#  'news',
#  'hawa',
#  'pheri',
#  'site',
#  'hya',
#  'kati',
#  'janu',
#  'batti',
#  'bujhdainau',
#  'kuarai',
#  'mind',
#  'vaisakyo',
#  'udla',
#  'jasto',
#  'katxau',
#  'kati',
#  'aru',
#  'kura',
#  'xodyo',
#  'tmro',
#  'lagna',
#  'ma',
#  'bishwash',
#  'bani',
#  'xaina',
#  'ramro',
#  'khasai',
#  'kti',
#  'nauthau',
#  'ai',
#  'ris',
#  'manxe',
#  'kati',
#  'kichki',
#  'gare',
#  'bho',
#  'hairan',
#  'parne',
#  'aaja',
#  'lagena',
#  'sakin',
#  'jasto',
#  'kaam',
#  'vane',
#  'sune',
#  'kura',
#  'matrai',
#  'afano',
#  'sochxau',
#  'bare',
#  'pitnu',
#  'tes',
#  'par',
#  'hero',
#  'dherai',
#  'banxas',
#  'mula',
#  'afno',
#  'bas',
#  'aukat',
#  'man',
#  'mero',
#  'mula',
#  'lagyo',
#  'barem',
#  'nabol',
#  'tehi',
#  'ai',
#  'gardina',
#  'paxi',
#  'garaula',
#  'din',
#  'thorai',
#  'padhe',
#  'vaihal',
#  'hajir',
#  'paryo',
#  'college',
#  'janai',
#  'bhayani',
#  'lagi',
#  'vane',
#  'gar',
#  'kura',
#  'yestai',
#  'tme',
#  'matrai',
#  'afno',
#  'kura',
#  'nagara',
#  'kina',
#  'gare',
#  'hatar',
#  'garnai',
#  'sakena',
#  'gardeyau',
#  'mero',
#  'thaha',
#  'rw',
#  'paula',
#  'kos',
#  'biased',
#  'halka',
#  'rahexau',
#  'chahi',
#  'vane',
#  'bhayana',
#  'jasto',
#  'chahi',
#  'laure',
#  'tori',
#  'haru',
#  'mula',
#  'ustai',
#  'sab',
#  'xan',
#  'vane',
#  'sundaina',
#  'pahila',
#  'kosai',
#  'gar',
#  'giddi',
#  'paxi',
#  'manxe',
#  'garna',
#  'sodhe',
#  'xas',
#  'afai',
#  'ma',
#  'bare',
#  'farak',
#  'ma',
#  'tero',
#  'pardaina',
#  'bas',
#  'ek',
#  'huna',
#  'sanga',
#  'nakhoj',
#  'dherai',
#  'close',
#  'bandha',
#  'ramro',
#  'gar',
#  'tero',
#  'nagara',
#  'afno',
#  'kura',
#  'ziddi',
#  'hijo',
#  'thulo',
#  'kura',
#  'garthis',
#  'khub',
#  'jhare',
#  'aaja',
#  'jasto',
#  'aukat',
#  'garxas',
#  'natak',
#  'dherai',
#  'ani',
#  'sune',
#  'kura',
#  'garxas',
#  'man',
#  'afno',
#  'marji',
#  'vane',
#  'ghar',
#  'mandainas',
#  'haru',
#  'kati',
#  'yesto',
#  'kura',
#  'sochxas',
#  'gardai',
#  'afu',
#  'sab',
#  'lagi',
#  'bachna',
#  'hola',
#  'vanda',
#  'dukha',
#  'manxas',
#  'sune',
#  'rw',
#  'thes',
#  'mero',
#  'kura',
#  'kai',
#  'sano',
#  'pheri',
#  'kura',
#  'kai',
#  'garthyo',
#  'aaja',
#  'tmro',
#  'dekhe',
#  'jasto',
#  'nahune',
#  'kaam',
#  'kaam',
#  'bigarihalexau',
#  'pahi',
#  'bhayanau',
#  'sikne',
#  'bujhne',
#  'bhayanu',
#  'vane',
#  'garxau',
#  'ater',
#  'kura',
#  'bani',
#  'pari',
#  'tmro',
#  'ater',
#  'garne',
#  'gar',
#  'kichki',
#  'jahi',
#  'vane',
#  'gardina',
#  'kehi',
#  'bela',
#  'bani',
#  'tmro',
#  'ajahi',
#  'ustai',
#  'vane',
#  'bhanera',
#  'pahi',
#  'jot',
#  'hudaina',
#  'yes',
#  'bhar',
#  'kos',
#  'yes',
#  'gar',
#  'kura',
#  'bishwash',
#  'hudaina',
#  'vanexi',
#  'halat',
#  'kunai',
#  'gardaina',
#  'kasai',
#  'tmro',
#  'kaam',
#  'gardaina',
#  'chatak',
#  'dherai',
#  'yes',
#  'ali',
#  'besi',
#  'gar',
#  'kura',
#  'ali',
#  'gar',
#  'hawa',
#  'kura',
#  'ali',
#  'khatam',
#  'bhayo',
#  'khatam',
#  'rahe',
#  'quality',
#  'hune',
#  'garexau',
#  'gari',
#  'khatam',
#  'use',
#  'khatam',
#  'rahe',
#  'geet',
#  'khatam',
#  'rahe',
#  'manxe',
#  'khal',
#  'rw',
#  'garera',
#  'yes',
#  'hawa',
#  'khatam',
#  'zindagi',
#  'kura',
#  'bigrisakyo',
#  'garna',
#  'paryo',
#  'hawa',
#  'kura',
#  'vane',
#  'bike',
#  'naleuna',
#  'khatam',
#  'lade',
#  'hune',
#  'bike',
#  'hijo',
#  'khatam',
#  'gari',
#  'khatam',
#  'dekhi',
#  'hudaithiyo',
#  'asti',
#  'bigrine',
#  'khatam',
#  'bhaayara',
#  'aaba',
#  'garxau',
#  'hawa',
#  'kura',
#  'jot',
#  'manxe',
#  'hun',
#  'jot',
#  'kura',
#  'yestai',
#  'sadhai',
#  'jot',
#  'bujhdaina',
#  'vanepani',
#  'jati',
#  'bujhdaina',
#  'kura',
#  'vane',
#  'bujhdaina',
#  'kura',
#  'bujhdaina',
#  'khai',
#  'kura',
#  'ajkal',
#  'bike',
#  'sakyo',
#  'ajkal',
#  'bigri',
#  'va',
#  'khatam',
#  'bigrera',
#  'sakyo',
#  'yes',
#  'dimag',
#  'bigri',
#  'khatam',
#  'yes',
#  'dimag',
#  'rahe',
#  'ghumna',
#  'bike',
#  'dindinai',
#  'ali',
#  'bigrisake',
#  'janirakh',
#  'jad',
#  'raksi',
#  'khanuhunna',
#  'birsera',
#  'birse',
#  'birse',
#  'pheri',
#  'bani',
#  'dherai',
#  'pheri',
#  'mero',
#  'birsine',
#  'raksi',
#  'dherai',
#  'lido',
#  'rahexau',
#  'raksi',
#  'garna',
#  'sakenau',
#  'control',
#  'raksi',
#  'garisak',
#  'dherai',
#  'tmro',
#  'asar',
#  'garda',
#  'jad',
#  'rw',
#  'raksi',
#  'dherai',
#  'gar',
#  'naramro',
#  'asar',
#  'jad',
#  'rw',
#  'raksi',
#  'hun',
#  'dherai',
#  'garda',
#  'accident',
#  'jad',
#  'rw',
#  'raski',
#  'gumau',
#  'control',
#  'manxe',
#  'afno',
#  'bas',
#  'aukat',
#  'bal',
#  'rw',
#  'bare',
#  'din',
#  'tero',
#  'kas',
#  'vaisakyo',
#  'psycho',
#  'vai',
#  'kya',
#  'ki',
#  'xaina',
#  'dimag',
#  'tero',
#  'nagar',
#  'kura',
#  'sa',
#  'aukat',
#  'tme',
#  'naparos',
#  'haru',
#  'haita',
#  'aukat',
#  'saba',
#  'dekhauna',
#  'diya',
#  'bal',
#  'ar',
#  'bare',
#  'kina',
#  'dherai',
#  'psycho',
#  'manxe',
#  'gar',
#  'psycho',
#  'kura',
#  'jasto',
#  'fail',
#  'kat',
#  'garo',
#  'xodyo',
#  'mo',
#  'bal',
#  'xodyo',
#  'dina',
#  'manxe',
#  'hune',
#  'choti',
#  'feri',
#  'vaiyo',
#  'fail',
#  'hune',
#  'padhda',
#  'vaiyo',
#  'fail',
#  'jati',
#  'parisakyo',
#  'garo',
#  'ma',
#  'fail',
#  'vayara',
#  'kat',
#  'dherai',
#  'kura',
#  'fail',
#  'kati',
#  'dherai',
#  'hunxas',
#  'xodyo',
#  'dharti',
#  'kina',
#  'herek',
#  'tai',
#  'choti',
#  'xodxas',
#  'question',
#  'hairan',
#  'lagena',
#  'kichki',
#  'ris',
#  'nagara',
#  'ris',
#  'kura',
#  'simana',
#  'ris',
#  'katisakyo',
#  'dherai',
#  'kichki',
#  'gar',
#  'pheri',
#  'hairan',
#  'ghar',
#  'gar',
#  'sadhai',
#  'hairan',
#  'sathi',
#  'yes',
#  'pari',
#  'lagena',
#  'kaam',
#  'to',
#  'saman',
#  'lagena',
#  'kaam',
#  'kahi',
#  'kina',
#  'lagena',
#  'kaam',
#  'manxe',
#  'pitnu',
#  'thorai',
#  'paxi',
#  'hatar',
#  'garmala',
#  'paxi',
#  'kaam',
#  'brisin',
#  'paxi',
#  'garne',
#  'jahi',
#  'vane',
#  'kaam',
#  'vane',
#  'kina',
#  'paxi',
#  'pheri',
#  'yes',
#  'paryo',
#  'pitna',
#  'khane',
#  'manxe',
#  'pitai',
#  'sudhera',
#  'manxe',
#  'khayara',
#  'pitai',
#  'kina',
#  'garne',
#  'jahi',
#  'hatar',
#  'garne',
#  'nagar',
#  'kaam',
#  'hatar',
#  'kina',
#  'xas',
#  'tai',
#  'hatar',
#  'mane',
#  'aru',
#  'mehenat',
#  'gar',
#  'ali',
#  'thorai',
#  'vanda',
#  'thorai',
#  'tai',
#  'garixas',
#  'laure',
#  'aaja',
#  'tori',
#  'sakena',
#  'tori',
#  'yestai',
#  'sakxas',
#  'laure',
#  'tori',
#  'kahi',
#  'laure',
#  'tori',
#  'kina',
#  'garxas',
#  'yesto',
#  'naramro',
#  'jahi',
#  'aaja',
#  'kaam',
#  'sakena',
#  'tori',
#  'kina',
#  'sakdaina',
#  'yetti',
#  'kaam',
#  'garera',
#  'ziddi',
#  'gardaixas',
#  'natak',
#  'thulo',
#  'khub',
#  'matrai',
#  'gar',
#  'thulo',
#  'jai',
#  'kura',
#  'khub',
#  'harek',
#  'natak',
#  'gar',
#  'kura',
#  'natak',
#  'tmro',
#  'dherai',
#  'ali',
#  'bho',
#  'chaatak',
#  'tmro',
#  'ali',
#  'throai',
#  'ater',
#  'gar',
#  'ali',
#  'ater',
#  'gar',
#  'sadhai',
#  'vane',
#  'mandaina',
#  'vane',
#  'manxe',
#  'namanne',
#  'kasto',
#  'sakinna',
#  'aaja',
#  'lagisakyo',
#  'jhyau',
#  'pheri',
#  'vane',
#  'garu',
#  'xaina',
#  'tmro',
#  'kaam',
#  'xaina',
#  'ramailo',
#  'zindagi',
#  'xaina',
#  'mero',
#  'sanga',
#  'paisa',
#  'xaina',
#  'data',
#  'kami',
#  'project',
#  'dherai',
#  'aaja',
#  'garmi',
#  'xaina',
#  'desh',
#  'ajkal',
#  'khasai',
#  'thik',
#  'halat',
#  'milera',
#  'corruption',
#  'gar',
#  'sabai',
#  'gambhir',
#  'avastha',
#  'desk',
#  'gambhir',
#  'vai',
#  'avastha',
#  'corruption',
#  'khojxan',
#  'garna',
#  'jsa',
#  'xaina',
#  'haru',
#  'corruption',
#  'aaya',
#  'ramro',
#  'garda',
#  'yehi',
#  'manxe',
#  'bigari',
#  'rajniti',
#  'sabi',
#  'kaam',
#  'rishaune',
#  'bani',
#  'yes',
#  'garna',
#  'sakdaina',
#  'control',
#  'dimag',
#  'afno',
#  'rw',
#  'kahi',
#  'kura',
#  'vane',
#  'garthyo',
#  'gaisakyo',
#  'dimag',
#  'yes',
#  'subhida',
#  'xaina',
#  'ramro',
#  'khasai',
#  'sewa',
#  'dukh',
#  'bitne',
#  'mero',
#  'zindagi',
#  'bho',
#  'saro',
#  'kina',
#  'yesto',
#  'gari',
#  'halla',
#  'gare',
#  'gar',
#  'ali',
#  'ajkal',
#  'halla',
#  'badhi',
#  'yes',
#  'garne',
#  'halla',
#  'yestai',
#  'xan',
#  'sathi',
#  'dekhauxan',
#  'matrai',
#  'sab',
#  'hope',
#  'suru',
#  'va',
#  'haina',
#  'badhi',
#  'saro',
#  'bigri',
#  'social',
#  'dherai',
#  'ajkal',
#  'media',
#  'garda',
#  'manxe',
#  'khatam',
#  'zindagi',
#  'hau',
#  'dherai',
#  'tmemanxe',
#  'fataha',
#  'glass',
#  'futa',
#  'manpari',
#  'dherai',
#  'sab',
#  'sanga',
#  'ramro',
#  'gardaina',
#  'keyboard',
#  'kaam',
#  'mobi',
#  'dherai',
#  'chalau',
#  'vaya',
#  'to',
#  'hijo',
#  'chowk',
#  'jhagada',
#  'vaya',
#  'hijo',
#  'thau',
#  'accident',
#  'news',
#  'hawa',
#  'jas',
#  'ha',
#  'mni',
#  'garera',
#  'hawa',
#  'viral',
#  'kura',
#  'va',
#  'manxe',
#  'sudhrene',
#  'na',
#  'vanera',
#  'harayo',
#  'garne',
#  'project',
#  'kata',
#  'manxe',
#  'jana',
#  'dui',
#  'harayaxan',
#  'hijo',
#  'manxe',
#  'ghar',
#  'haina',
#  'banse',
#  'ekxin',
#  'dulna',
#  'kati',
#  'sake',
#  'fataha',
#  'garinas',
#  'choti',
#  'vanexi',
#  'kaam',
#  'fataha',
#  'jhan',
#  'tme',
#  'ajkal',
#  'va',
#  'rahexau',
#  'kina',
#  'dherai',
#  'pheri',
#  'yeti',
#  'chatak',
#  'vayana',
#  'kaam',
#  'gare',
#  'sab',
#  'ulto',
#  'kyura',
#  'garna',
#  'number',
#  'ulto',
#  'nagar',
#  'dheria',
#  'kura',
#  'ulto',
#  'gayo',
#  'batti',
#  'garna',
#  'sabai',
#  'sakinna',
#  'ajkal',
#  'bishwash',
#  'sakinna',
#  'aja',
#  'aaba',
#  'kaam',
#  'social',
#  'hun',
#  'dherai',
#  'media',
#  'ajkla',
#  'scam',
#  'online',
#  'saman',
#  'site',
#  'vane',
#  'gardina',
#  'jasto',
#  'deliver',
#  'mero',
#  'hijo',
#  'game',
#  'sathi',
#  'hare',
#  'paisa',
#  'chori',
#  'hijo',
#  'vaya',
#  'ar',
#  'saman',
#  'chori',
#  'gau',
#  'hijo',
#  'vaya',
#  'vayana',
#  'yesari',
#  'rw',
#  ...]

# %%
corpus1 = set(pos_corpus)
corpus2= set(neg_corpus)

# %%
common = corpus1.intersection(corpus2)

# %%
common
# Out:
# {'appreciate',
#  'birodh',
#  'hotel',
#  'geet',
#  'bhayani',
#  'utthaaye',
#  'maayaa',
#  'paanii',
#  'kaaraimaa',
#  'samasya',
#  'aahvaan',
#  'mhaan',
#  'jggaa',
#  'nmitthaa',
#  'soche',
#  'samiksha',
#  'hiddiraachu',
#  'citizen',
#  'hain',
#  'ex',
#  'honii',
#  'alptr',
#  'berojgari',
#  'say',
#  'dekhaaer',
#  'manushya',
#  'cai',
#  'tme',
#  'diye',
#  'baattomaa',
#  'kaarbaahii',
#  'pratik',
#  'aajwtw',
#  'kukhyaat',
#  'hum',
#  'paisa',
#  'hope',
#  'doka',
#  'parne',
#  'sg',
#  'naam',
#  'broomer',
#  'kesiilaaii',
#  'mn',
#  'hau',
#  'yes',
#  'bhiddiyo',
#  'njikkaae',
#  'university',
#  'prdhaanmntrii',
#  'jstai',
#  'sochya',
#  'bauddh',
#  'smrdhd',
#  'tesai',
#  'hidnai',
#  'apraadhii',
#  'grchn',
#  'khayara',
#  'bisvs',
#  'sndip',
#  'netaalaaii',
#  'aamaa',
#  'sahara',
#  'back',
#  'nikai',
#  'bhuln',
#  'jiban',
#  'yauttai',
#  'c',
#  'yaar',
#  'bhnnskchu',
#  'jnmaayo',
#  'suter',
#  'us',
#  'smy',
#  'raajy',
#  'pokhara',
#  'le',
#  'hller',
#  'vridhhi',
#  'samarpan',
#  'dekhin',
#  'vanera',
#  'naagrik',
#  'hjaar',
#  'bhnyaa',
#  'dindhaaddai',
#  'rhi',
#  'aaphnai',
#  'bholi',
#  'sakxau',
#  'bhen',
#  'baatto',
#  'lage',
#  'jti',
#  'asttreliyaa',
#  'sndhyaa',
#  'aausi',
#  'sdhain',
#  'holaa',
#  'nsrau',
#  'sound',
#  'herer',
#  'kina',
#  'cunaavmaa',
#  'ml',
#  'laag',
#  'naya',
#  'khayepachi',
#  'raamro',
#  'swasthya',
#  'thikai',
#  'sharing',
#  'thie',
#  'garna',
#  'kaatthmaaddaun',
#  'unihru',
#  'grdai',
#  'netaahru',
#  'news',
#  'yesto',
#  'ddaakaahru',
#  'kulcer',
#  'jaatrai',
#  'kasta',
#  'sundaichn',
#  'quality',
#  'grm',
#  'nepaal',
#  'prakriti',
#  'dhulo',
#  'yaa',
#  'pustak',
#  'ddonesn',
#  'ajhai',
#  'suk',
#  'ksto',
#  'daanv',
#  'time',
#  'kettii',
#  'on',
#  'nbolaun',
#  'lkhettne',
#  'laacaarii',
#  'jaabo',
#  'simana',
#  'grn',
#  'aartii',
#  'ngrne',
#  'man',
#  'timraa',
#  'sikne',
#  'yestaa',
#  'stop',
#  'laai',
#  'dekhinchn',
#  'price',
#  'vs',
#  'xa',
#  'khasai',
#  'maan',
#  'bicraa',
#  'sudhar',
#  'srkaarii',
#  'sanrakshan',
#  'bichara',
#  'bolne',
#  'jutthaa',
#  'paryo',
#  'testo',
#  'kine',
#  'vyaktitwa',
#  'biraamii',
#  'karyakram',
#  'xoro',
#  'haita',
#  'pol',
#  'kti',
#  'sewa',
#  'vane',
#  'aandoln',
#  'chinta',
#  'vaishaakh',
#  'sanskriti',
#  'family',
#  'un',
#  'vishwas',
#  'posttmaa',
#  'bnaauchu',
#  'labs',
#  'kaanun',
#  'sunn',
#  'data',
#  'grv',
#  'performance',
#  'gridie',
#  'ptre',
#  'parena',
#  'alxi',
#  'live',
#  'raamrii',
#  'online',
#  'pheri',
#  'pryog',
#  'hdai',
#  'baaji',
#  'thorai',
#  'market',
#  'wow',
#  'bhne',
#  'photto',
#  'bhekaa',
#  'ananda',
#  'rahe',
#  'scores',
#  'lukaauchn',
#  'shanti',
#  'vaataavrnn',
#  'ge',
#  'yeti',
#  'viddmvnaa',
#  'wish',
#  'naanikaa',
#  'mann',
#  'bhnin',
#  'surkssaakrmii',
#  'sng',
#  'tyaahi',
#  'vyaktigat',
#  'nepali',
#  'haamii',
#  'garne',
#  'dhnyvaad',
#  'vikaas',
#  'nprni',
#  'bike',
#  'teammate',
#  'laagekaa',
#  'bicauliyaa',
#  'rksii',
#  'deu',
#  'khaayo',
#  'hernus',
#  'nraamro',
#  'baabai',
#  'bhaasaamaa',
#  'bhnchu',
#  'jntaa',
#  'sochera',
#  'video',
#  'badhi',
#  'gnntntr',
#  'gen',
#  'expectation',
#  'kadam',
#  'dindain',
#  'pare',
#  'byvhaar',
#  'sphaa',
#  'rai',
#  'gaaddii',
#  'cheker',
#  'pa',
#  'sambhavana',
#  'chlnkaa',
#  'rhekaa',
#  'out',
#  'mnaaideu',
#  'khilyai',
#  'pragati',
#  'mhngo',
#  'aafna',
#  'jeevan',
#  'rahexau',
#  'sutdaa',
#  'tthuulo',
#  'baadr',
#  'smptti',
#  'baahun',
#  'bhelaa',
#  'afnai',
#  'dinbhri',
#  'krtvybaatt',
#  'khatra',
#  'leu',
#  'rhechn',
#  'hiddn',
#  'mitho',
#  'haru',
#  'khane',
#  'haahaa',
#  'haaler',
#  'jityo',
#  'janta',
#  'caaddai',
#  'janu',
#  'mehenat',
#  'lost',
#  'maagnehruu',
#  'hawa',
#  'bhasha',
#  'pchi',
#  'mane',
#  'aaaijaa',
#  'movie',
#  'bic',
#  'niraas',
#  'ujyalo',
#  'use',
#  'daanb',
#  'abhivyakti',
#  'vana',
#  'shriimtii',
#  'tthiik',
#  'bhaat',
#  'thpdai',
#  'billaa',
#  'purna',
#  'raakhiekaa',
#  'paanc',
#  'sakiyo',
#  'sddkmaa',
#  'aat',
#  'hunn',
#  'laager',
#  'bata',
#  'ai',
#  'bhnos',
#  'tero',
#  'prm',
#  'pre',
#  'pryo',
#  'bideshi',
#  'of',
#  'munche',
#  'kaa',
#  'kai',
#  'klaas',
#  'sano',
#  'anaadhikrit',
#  'mjaak',
#  'try',
#  'collect',
#  'cillaa',
#  'surkssit',
#  'binaa',
#  'hune',
#  'prmaann',
#  'aaen',
#  'staff',
#  'bacha',
#  'grchaun',
#  'everest',
#  'rarmo',
#  'sangharsha',
#  'garos',
#  'ryaaliimaa',
#  'esto',
#  'pustaa',
#  'bhye',
#  'hurke',
#  'paaun',
#  'eid',
#  'vai',
#  'cleaner',
#  'es',
#  'with',
#  'gideu',
#  'ysto',
#  'bhaye',
#  'na',
#  'tmi',
#  'dukhi',
#  'level',
#  'bhottrlaaii',
#  'bhetghat',
#  'choddeki',
#  'proud',
#  'question',
#  'surkssaa',
#  'nyay',
#  'khushi',
#  'pi',
#  'sabai',
#  'garnu',
#  'these',
#  'bjaarmaa',
#  'myaacis',
#  'baacdin',
#  'pddke',
#  'posture',
#  'khaan',
#  'ktai',
#  'herda',
#  'naataavaad',
#  'kmaaikaa',
#  'phrk',
#  'prayas',
#  'rajniti',
#  'laakhau',
#  'tn',
#  'sampannata',
#  'agaaddi',
#  'herna',
#  'sake',
#  'uti',
#  'vriddhi',
#  'maatto',
#  'shiksha',
#  'ti',
#  'euta',
#  'who',
#  'karan',
#  'then',
#  'choti',
#  'saarhai',
#  'afno',
#  'phaarm',
#  'smaater',
#  'krssi',
#  'pddhn',
#  'matra',
#  'npaakn',
#  'baa',
#  'pryaa',
#  'ddhuku',
#  'bato',
#  'mero',
#  'yuvaalaai',
#  'dekhaavotti',
#  'aaja',
#  'ar',
#  'daan',
#  'payo',
#  'nddhaatt',
#  'sbjii',
#  'psinaa',
#  'bnaaun',
#  'videsh',
#  'gaye',
#  'dimaag',
#  'kaardd',
#  'aaj',
#  'aaer',
#  'haancn',
#  'dhilo',
#  'teti',
#  'caahin',
#  'haamro',
#  'kati',
#  'sii',
#  't',
#  'janata',
#  'tax',
#  'garxan',
#  'bslaas',
#  'sambhav',
#  'thaha',
#  'skdin',
#  'bddhii',
#  'chamak',
#  'maarmaa',
#  'bahir',
#  'hidd',
#  'lastai',
#  'khusi',
#  'baadhk',
#  'dier',
#  'raasttrptii',
#  'government',
#  'snsaar',
#  'rw',
#  'jwala',
#  'groski',
#  'piun',
#  'thiiin',
#  'dekhi',
#  'xaina',
#  'rang',
#  'app',
#  'andhyaro',
#  'vikaaskaae',
#  'srttiphikett',
#  'and',
#  'kaarykrtaa',
#  'dekhe',
#  'nepal',
#  'gidd',
#  'yehi',
#  'jati',
#  'nepaali',
#  'meyr',
#  'sike',
#  'sbailaai',
#  'pchaaddii',
#  'kohi',
#  'kahi',
#  'laaidinthe',
#  'haju',
#  'kehii',
#  'anusar',
#  'baatt',
#  'dhotii',
#  'httaaudaa',
#  'prne',
#  'payment',
#  'thien',
#  'saalaa',
#  'garnai',
#  'thiyo',
#  'skin',
#  'laayk',
#  'privaar',
#  'kicdai',
#  'mnpri',
#  'naagriktaa',
#  'baanii',
#  'nge',
#  'padhe',
#  'experience',
#  'purnata',
#  'ghttiyaa',
#  'bachelor',
#  'ki',
#  'average',
#  'mathi',
#  'timii',
#  'lier',
#  'bhaa',
#  'kaae',
#  'jhgddaa',
#  'love',
#  'ttraaphik',
#  'jhn',
#  'bnaau',
#  'vttaa',
#  'laagii',
#  'pade',
#  'kamauna',
#  'viplv',
#  'gaaro',
#  'zindagi',
#  'aankhaalaaii',
#  'bhavishya',
#  'tai',
#  'implement',
#  'baadhaa',
#  'haalmaa',
#  'nlaager',
#  'haae',
#  'enjoy',
#  'tystai',
#  'vaalaa',
#  'it',
#  'hlyo',
#  'antrraassttriy',
#  'anubhav',
#  'basna',
#  'cinthen',
#  'dekhn',
#  'aru',
#  'tyhaankaa',
#  'taste',
#  'bybsaay',
#  'ktaa',
#  'jindgii',
#  'ekdin',
#  'jntaahruu',
#  'bhnthii',
#  'so',
#  'paaltu',
#  'khppis',
#  'ddigrii',
#  'kheddai',
#  'afai',
#  'vaya',
#  'vaira',
#  'bll',
#  'euttai',
#  'ddhilo',
#  'garnw',
#  'sam',
#  'teamwork',
#  'xas',
#  'jane',
#  'chitto',
#  'are',
#  'pahila',
#  'plett',
#  'chau',
#  'swag',
#  'her',
#  'kam',
#  'jvos',
#  'posstt',
#  'pherii',
#  'bnos',
#  'rangai',
#  'dhuvaan',
#  'halat',
#  'aaphuu',
#  'snco',
#  'maajhe',
#  'mhsus',
#  'yhii',
#  'samudayik',
#  'anii',
#  'birthday',
#  'krmcaarii',
#  'arkai',
#  'barsa',
#  'caahi',
#  'laptop',
#  'paap',
#  'prkhe',
#  'tysto',
#  'dhaarmik',
#  'duhkh',
#  'maasttr',
#  'garo',
#  'ulttai',
#  'dekhdaa',
#  'jldaichn',
#  'laagdo',
#  'padhai',
#  'react',
#  'bhrssttaacaar',
#  'timletw',
#  'tthhr',
#  'jun',
#  'tyhi',
#  'khusii',
#  'jntaalaaii',
#  'lyrics',
#  'haanekaa',
#  'pic',
#  'ntr',
#  'chetana',
#  'aalu',
#  'gardai',
#  'peop',
#  'khulaaunu',
#  'paa',
#  'jas',
#  'bhndaa',
#  'product',
#  'chdden',
#  'cin',
#  'katha',
#  'khan',
#  'aatmaa',
#  'belaaytii',
#  'ttim',
#  'guttkhaa',
#  'herdai',
#  'himal',
#  'khbr',
#  'thik',
#  'acting',
#  'chn',
#  'vidyaarthii',
#  'sahajata',
#  'bitaune',
#  'halka',
#  'tmro',
#  'troll',
#  'phohor',
#  'yojana',
#  'gari',
#  'purne',
#  'rojgar',
#  'karyalaya',
#  'rksi',
#  'mirmire',
#  'chaaeraahru',
#  'sathi',
#  'pulish',
#  'ytro',
#  'bela',
#  'this',
#  'rojgaarii',
#  'bcpn',
#  'kp',
#  'uslaai',
#  'aarthik',
#  'nepaallaaii',
#  'bhaya',
#  'bnd',
#  'biplv',
#  'dimaakh',
#  'dataset',
#  'ghddii',
#  'baaki',
#  'haalne',
#  'mm',
#  'toilet',
#  'laagyaa',
#  'khaane',
#  'manai',
#  'andar',
#  'bjaar',
#  'tayari',
#  'bas',
#  'hi',
#  'lyaaer',
#  'sjaay',
#  'paatkii',
#  'anyaay',
#  'naitikta',
#  'mekap',
#  'uni',
#  'muttu',
#  'exam',
#  'record',
#  'kisaan',
#  'naaune',
#  'vanda',
#  'laaiin',
#  'haane',
#  'paas',
#  'maa',
#  'baal',
#  'bhyo',
#  'anubhv',
#  'profession',
#  'cukne',
#  'no',
#  'ds',
#  'garmi',
#  'niskin',
#  'daajai',
#  'garexau',
#  'dimag',
#  'bnaaunu',
#  'srkaar',
#  'daaju',
#  'cddhn',
#  'samay',
#  'tehi',
#  'ddelibhrii',
#  'aaphno',
#  'philimhru',
#  'matrai',
#  'curott',
#  'hern',
#  'sahi',
#  'banauna',
#  'nomore',
#  'gren',
#  'grie',
#  'garda',
#  'sarkar',
#  'ksai',
#  'paain',
#  'kunai',
#  'bhrmaa',
#  'kehi',
#  'caahe',
#  'nmilnegrii',
#  'vip',
#  'nepaalihru',
#  'mtr',
#  'raakhn',
#  'tiirth',
#  'estai',
#  'uhaan',
#  'holaajsto',
#  'hisaab',
#  'bikaas',
#  'je',
#  'tgaaro',
#  'subhkaamnaa',
#  'banaune',
#  'kin',
#  'ramrai',
#  'ajkal',
#  'jggaalaaii',
#  'middiyaa',
#  'laagyo',
#  'sute',
#  'taaraa',
#  'aslii',
#  'hoina',
#  'ek',
#  'from',
#  'dekhina',
#  'haalins',
#  'smrddii',
#  'smaan',
#  'thiye',
#  'svaarth',
#  'phttyaangro',
#  'chin',
#  'ab',
#  'cldai',
#  'ghmndd',
#  'kaammaa',
#  'sbai',
#  'hoin',
#  'njaanyaa',
#  'bitaye',
#  'pr',
#  'do',
#  'book',
#  'bihaanai',
#  'missing',
#  'jhai',
#  'lagi',
#  'dde',
#  'kelayenw',
#  'dekhyaa',
#  'aafanta',
#  'ekxin',
#  'nsunaairaakh',
#  'trust',
#  'khaanaa',
#  'bhndai',
#  'spsstt',
#  'grib',
#  'bhner',
#  'smm',
#  'ysrii',
#  'khrc',
#  'kiraa',
#  'haaldaa',
#  'company',
#  'gaalii',
#  'snakes',
#  'garera',
#  'daai',
#  'tthik',
#  'eklai',
#  'mah',
#  'samadhan',
#  'features',
#  'nt',
#  'ramesh',
#  'grchu',
#  'ley',
#  'hraai',
#  'kmentt',
#  'hunthyo',
#  'jnaa',
#  'grnupr',
#  'jaatraa',
#  'kuraa',
#  'saathi',
#  'haal',
#  'ali',
#  'klilaa',
#  'aja',
#  'muulaahruu',
#  'prkin',
#  'vayana',
#  'for',
#  'pu',
#  'ghanta',
#  'cott',
#  'haaes',
#  'paahidain',
#  'dhikkaar',
#  'hilo',
#  'xan',
#  'xitai',
#  'samaya',
#  'becne',
#  'dekhnu',
#  'bsdaa',
#  'uslaaii',
#  'asvikaar',
#  'tel',
#  'netaa',
#  'base',
#  'ssto',
#  'pulis',
#  'kasari',
#  'dukh',
#  'kyaa',
#  'xu',
#  'nyaay',
#  'game',
#  'first',
#  'pauxan',
#  'meyar',
#  'ketti',
#  'xau',
#  'hraaudau',
#  'nskne',
#  'prabhavit',
#  'jntaakai',
#  'anuhaar',
#  'kpddaa',
#  'grer',
#  'jyaan',
#  'va',
#  'jana',
#  'bhy',
#  'huna',
#  'khaau',
#  'tthulaa',
#  'adhikar',
#  'draajmaa',
#  'mtlb',
#  'sk',
#  'jeeban',
#  'andhera',
#  'sjilo',
#  'bidesh',
#  'milera',
#  'hun',
#  'par',
#  'harek',
#  'smaatnai',
#  'doss',
#  'nagara',
#  'dekhepchi',
#  'bddhyo',
#  'niym',
#  'sanga',
#  'sshstr',
#  'adhikaar',
#  'shbd',
#  'kholer',
#  'gyo',
#  'gareu',
#  'gareka',
#  'gre',
#  'bhaar',
#  'aayo',
#  'pain',
#  'hge',
#  'dekhnai',
#  'chorii',
#  'paaline',
#  'aaunu',
#  'grh',
#  'brss',
#  'sashaktikaran',
#  'garney',
#  'bhrdaichn',
#  'smjhnaa',
#  'ke',
#  'jindagi',
#  'grin',
#  'bokne',
#  'protecting',
#  'swatantrata',
#  'tesro',
#  'srsphaai',
#  'khaa',
#  'timitw',
#  'laagen',
#  'jasari',
#  'aaya',
#  'bhayo',
#  'bho',
#  'paisaa',
#  'gadi',
#  'rgt',
#  'sb',
#  'ger',
#  'thiyen',
#  'dekher',
#  'tlb',
#  'baaiik',
#  'smaacaar',
#  'tthaau',
#  'chu',
#  'dhokaa',
#  'college',
#  'bhawishya',
#  'gardaina',
#  'naammaa',
#  'aakarshan',
#  'thukk',
#  'thau',
#  'svaasthy',
#  'hami',
#  'bhaiske',
#  'shyog',
#  'hudain',
#  'baau',
#  'ttuddikhel',
#  'ghnnttaa',
#  'tyhii',
#  'jok',
#  'ta',
#  'grthe',
#  'choraa',
#  'lokendr',
#  'economic',
#  'khana',
#  'alik',
#  'gaaddimaa',
#  'body',
#  'jo',
#  'baaje',
#  'professors',
#  'mrekaa',
#  ...}

# %%
len(common)
# Out:
# 1483

# %%
len(pos_corpus)
# Out:
# 13551

# %%
len(neg_corpus)
# Out:
# 7992

# %%
 len(corpus1)
# Out:
# 4214

# %%
len(corpus2)
# Out:
# 3019

# %%
from collections import Counter
pos_df = pd.DataFrame(Counter(pos_corpus).most_common(20))
neg_df = pd.DataFrame(Counter(neg_corpus).most_common(20))

# %%
pos_df
# Out:
#          0    1
# 0    ramro  148
# 1     haru  132
# 2       xa  120
# 3     mero   98
# 4     kaam   97
# 5      hun   93
# 6      maa   76
# 7   dherai   72
# 8     kura   70
# 9      man   69
# 10     din   67
# 11    aaja   59
# 12  raamro   55
# 13  jeevan   53
# 14     par   52
# 15     gar   51
# 16    desh   51
# 17     grn   49
# 18    gare   45
# 19      ki   44

# %%
neg_df
# Out:
#           0   1
# 0      haru  98
# 1     xaina  97
# 2      kaam  71
# 3      kura  50
# 4       man  46
# 5    dherai  43
# 6      mero  42
# 7       maa  38
# 8     ramro  37
# 9       hun  36
# 10     hune  36
# 11       xa  36
# 12      gar  35
# 13     kami  32
# 14  samajik  31
# 15     aaja  30
# 16     vane  30
# 17     desh  29
# 18      hru  28
# 19      ali  27

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.iloc[:,:1]

# %%
X
# Out:
#                        Text
# 0                   sanchai
# 1                tmro khabr
# 2          naulo sunau naya
# 3               thikai mero
# 4           ramailo zindagi
# ...                     ...
# 4953           haancn bncro
# 4954    khuttttaa bncro maa
# 4955    dherai manxe harami
# 4956  kaa bas garera harami
# 4957          number harami
#
# [4357 rows x 1 columns]

# %%
y= df.iloc[:,-1]

# %%
y
# Out:
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
#        ...
# 4953    1.0
# 4954    0.0
# 4955    0.0
# 4956    0.0
# 4957    0.0
# Name: Score, Length: 4357, dtype: float64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %% [markdown]
# # TFIDF

# %%
from sklearn.feature_extraction.text import CountVectorizer ,TfidfVectorizer
tfidf = TfidfVectorizer(max_features=2500)

# %%
X_train_tfidf = tfidf.fit_transform(X_train['Text']).toarray()
X_test_tfidf = tfidf.transform(X_test['Text']).toarray()

# %%
X_train_tfidf.shape
# Out:
# (3485, 2500)

# %%
tfidf.vocabulary_
# Out:
# {'hun': 856,
#  'ngrdaa': 1502,
#  'aphelnaa': 134,
#  'kaarnn': 989,
#  'hune': 859,
#  'biplb': 369,
#  'jnm': 935,
#  'yestai': 2468,
#  'hru': 848,
#  'chinta': 443,
#  'helmett': 819,
#  'pchaaddi': 1657,
#  'anivaary': 120,
#  'gridain': 773,
#  'sewa': 2069,
#  'swasthya': 2204,
#  'vridhhi': 2432,
#  'pr': 1730,
#  'nikai': 1515,
#  'lyaipuraayo': 1296,
#  'timii': 2267,
#  'bhndaa': 299,
#  'man': 1332,
#  'ananda': 107,
#  'vyaktitwa': 2435,
#  'prabhavit': 1735,
#  'andar': 110,
#  'bahir': 212,
#  'asantushti': 154,
#  'garos': 728,
#  'gardapani': 706,
#  'nava': 1468,
#  'kasto': 1017,
#  'jatti': 894,
#  'you': 2481,
#  'have': 813,
#  'respect': 1902,
#  'my': 1438,
#  'khaau': 1053,
#  'kettii': 1038,
#  'curott': 505,
#  'top': 2289,
#  'kettaa': 1035,
#  'tesai': 2219,
#  'maarin': 1314,
#  'mridain': 1410,
#  'ki': 1114,
#  'dherai': 578,
#  'sab': 1966,
#  'saubhagya': 2051,
#  'gar': 697,
#  'vyaktigat': 2434,
#  'sampannata': 2025,
#  'anubhoga': 126,
#  'paripati': 1634,
#  'saphalta': 2040,
#  'karyanvayan': 1013,
#  'ngrii': 1503,
#  'thie': 2238,
#  'thuprai': 2257,
#  'mekap': 1354,
#  'ke': 1026,
#  'maadhym': 1301,
#  'dinu': 608,
#  'jrurii': 957,
#  'grnu': 781,
#  'thiyo': 2248,
#  'bhne': 302,
#  'ddraaun': 543,
#  'video': 2415,
#  'pradarshan': 1737,
#  'ujjwala': 2366,
#  'aaphain': 35,
#  'chu': 461,
#  'khushii': 1109,
#  'chnauttmaa': 450,
#  'ko': 1145,
#  'uddaaiidine': 2361,
#  'kpaal': 1157,
#  'pherii': 1679,
#  'lgaaepchi': 1264,
#  'average': 166,
#  'mero': 1357,
#  'rahyo': 1871,
#  'experience': 667,
#  'aaja': 24,
#  'bhari': 266,
#  'din': 605,
#  'kadam': 1000,
#  'harek': 808,
#  'tmro': 2284,
#  'afno': 85,
#  'kura': 1190,
#  'nepaal': 1481,
#  'aahvaan': 18,
#  'bnd': 393,
#  'maa': 1299,
#  'haann': 796,
#  'hudain': 854,
#  'vai': 2402,
#  'paryo': 1642,
#  'mryaadit': 1416,
#  'bnaaunu': 390,
#  'caahi': 419,
#  'xaina': 2450,
#  'grn': 778,
#  'kuraae': 1192,
#  'kehii': 1029,
#  'laayk': 1233,
#  'yhaan': 2472,
#  'pratik': 1752,
#  'pratibha': 1750,
#  'banau': 216,
#  'shakti': 2074,
#  'gr': 757,
#  'kina': 1119,
#  'gare': 710,
#  'hatar': 811,
#  'srkaar': 2175,
#  'duii': 632,
#  'kettaakettii': 1036,
#  'tii': 2262,
#  'uniihru': 2376,
#  'pryo': 1805,
#  'jnaa': 932,
#  'bhe': 278,
#  'rhnu': 1910,
#  'sdhai': 2062,
#  'ge': 736,
#  'thpdai': 2250,
#  'tthulaa': 2325,
#  'mhl': 1369,
#  'andhera': 113,
#  'nirasha': 1522,
#  'khushi': 1108,
#  'aja': 96,
#  'thulo': 2255,
#  'hos': 845,
#  'ruttine': 1934,
#  'party': 1640,
#  'prne': 1790,
#  'haannu': 797,
#  'laai': 1219,
#  'kik': 1117,
#  'desh': 571,
#  'chn': 449,
#  'bhettiinu': 284,
#  'challenge': 430,
#  'phohor': 1691,
#  'bhaagymaanii': 255,
#  'aaphno': 38,
#  'trash': 2296,
#  'aaer': 13,
#  'bidesh': 352,
#  'paae': 1583,
#  'kaam': 980,
#  'bachelor': 197,
#  'time': 2266,
#  'paxi': 1649,
#  'garne': 724,
#  'ramailo': 1883,
#  'sakiyo': 1999,
#  'garera': 715,
#  'haru': 810,
#  'paaun': 1605,
#  'sathai': 2047,
#  'muskan': 1433,
#  'jeevan': 898,
#  'hijo': 831,
#  'ramrai': 1885,
#  'bicraa': 349,
#  'garda': 703,
#  'xito': 2455,
#  'baa': 170,
#  'ds': 624,
#  'laager': 1211,
#  'xa': 2448,
#  'choro': 459,
#  'lt': 1290,
#  'jaabo': 872,
#  'bhnne': 309,
#  'cintaa': 469,
#  'jus': 968,
#  'nlig': 1541,
#  'thaah': 2225,
#  'mukh': 1422,
#  'khaadainau': 1043,
#  'saathihru': 1962,
#  'tim': 2265,
#  'euttaa': 658,
#  'nsaa': 1556,
#  'bhner': 305,
#  'proddktthru': 1792,
#  'aaphnaa': 36,
#  'dheraibhndaa': 579,
#  'bikri': 368,
#  'bhekaa': 279,
#  'sikkaamaa': 2116,
#  'trishul': 2299,
#  'gaaii': 686,
#  'griyo': 777,
#  'sarai': 2041,
#  'alxi': 104,
#  'afnai': 84,
#  'paye': 1650,
#  'ramro': 1886,
#  'bacha': 196,
#  'kti': 1177,
#  'samajik': 2008,
#  'samanvay': 2010,
#  'awasar': 168,
#  'sahbhagita': 1982,
#  'hola': 842,
#  'vaisakyo': 2404,
#  'aaunu': 58,
#  'sir': 2121,
#  'chahi': 426,
#  'cai': 422,
#  'kmeddii': 1140,
#  'otth': 1577,
#  'grnii': 780,
#  'nprni': 1550,
#  'jsto': 962,
#  'tr': 2294,
#  'prlaa': 1785,
#  'kmtaa': 1143,
#  'niym': 1534,
#  'thien': 2239,
#  'bike': 367,
#  'ytii': 2493,
#  'pchaaddii': 1658,
#  'rmaaiilo': 1918,
#  'ddulaaun': 544,
#  'raakher': 1848,
#  'caahin': 420,
#  'skchu': 2131,
#  'piipii': 1713,
#  'praapt': 1731,
#  'ksrii': 1172,
#  'mlaaii': 1395,
#  'gryo': 784,
#  'ysto': 2491,
#  'ddhuku': 532,
#  'tn': 2285,
#  'lntthk': 1282,
#  'khan': 1060,
#  'vane': 2406,
#  'garxau': 731,
#  'ater': 159,
#  'daai': 509,
#  'sundaa': 2190,
#  'pol': 1722,
#  'muttu': 1435,
#  'khbr': 1073,
#  'rbi': 1893,
#  'ta': 2207,
#  'bhaye': 274,
#  'sapana': 2038,
#  'grne': 779,
#  'grchn': 761,
#  'sidhei': 2106,
#  'manxe': 1339,
#  'kati': 1020,
#  'kichki': 1116,
#  'pic': 1707,
#  'rhe': 1904,
#  'laagii': 1214,
#  'aakarshan': 28,
#  'badha': 201,
#  'yhaa': 2471,
#  'ytikai': 2494,
#  'jo': 945,
#  'postt': 1726,
#  'photto': 1697,
#  'laagi': 1213,
#  'kehi': 1028,
#  'ruttinelaaii': 1935,
#  'bideshmaa': 355,
#  'srsphaai': 2178,
#  'khicer': 1078,
#  'bhndai': 300,
#  'hudai': 853,
#  'bolau': 397,
#  'sathi': 2048,
#  'smaaj': 2147,
#  'badlu': 210,
#  'rangai': 1888,
#  'laparwahi': 1246,
#  'prajatantra': 1740,
#  'pheri': 1678,
#  'bani': 222,
#  'wow': 2447,
#  'thanks': 2231,
#  'anniversary': 122,
#  'for': 680,
#  'nice': 1510,
#  'the': 2234,
#  'ndinu': 1479,
#  'ghddii': 743,
#  'ksailaaii': 1171,
#  'garnu': 726,
#  'vayani': 2410,
#  'garo': 727,
#  'tyhi': 2354,
#  'cor': 496,
#  'sk': 2129,
#  'js': 958,
#  'raamro': 1855,
#  'smmaan': 2155,
#  'paaiyos': 1590,
#  'birodh': 371,
#  'kuraamaa': 1193,
#  'laage': 1207,
#  'ani': 117,
#  'lugaa': 1291,
#  'lgaaer': 1265,
#  'ali': 100,
#  'sjilo': 2128,
#  'jasto': 892,
#  'sabai': 1967,
#  'gnntntr': 754,
#  'pre': 1761,
#  'khilyai': 1080,
#  'mn': 1397,
#  'kam': 1006,
#  'gatilo': 732,
#  'garexaa': 717,
#  'bhssttaacaarii': 333,
#  'naataavaad': 1447,
#  'khrc': 1097,
#  'raajesh': 1842,
#  'hstaantrnn': 851,
#  'ciyaa': 476,
#  'daaii': 510,
#  'choti': 460,
#  'bhavishya': 271,
#  'ujjwal': 2365,
#  'rakh': 1880,
#  'shiksha': 2087,
#  'naya': 1470,
#  'xau': 2453,
#  'nraamro': 1555,
#  'ksto': 1174,
#  'pddhn': 1666,
#  'lau': 1250,
#  'khusi': 1110,
#  'joddii': 948,
#  'bhyo': 344,
#  'ddhilo': 531,
#  'bihe': 364,
#  'sano': 2035,
#  'kai': 1004,
#  'nepal': 1492,
#  'langhana': 1244,
#  'adhikar': 81,
#  'skinn': 2138,
#  'purai': 1825,
#  'kaatthmaanddau': 998,
#  'khel': 1074,
#  'clcitrhruu': 479,
#  'kheln': 1076,
#  'hern': 827,
#  'ropnupr': 1928,
#  'ruukh': 1937,
#  'bddhii': 241,
#  'haamii': 793,
#  'khosidie': 1091,
#  'shriipec': 2098,
#  'jane': 887,
#  'sake': 1994,
#  'lagne': 1242,
#  'garmi': 721,
#  'sanga': 2031,
#  'par': 1628,
#  'data': 522,
#  'edit': 643,
#  'haaldaa': 789,
#  'grer': 770,
#  'haalne': 791,
#  'vayana': 2409,
#  'astitwa': 156,
#  'us': 2388,
#  'game': 696,
#  'lage': 1239,
#  'hare': 807,
#  'company': 488,
#  'rarmo': 1890,
#  'appreciate': 136,
#  'tara': 2212,
#  'nagare': 1456,
#  'hunu': 864,
#  'college': 487,
#  'professors': 1795,
#  'kuraa': 1191,
#  'hrek': 847,
#  'huna': 857,
#  'prabhav': 1734,
#  'prakriti': 1743,
#  'rahi': 1870,
#  'kharab': 1065,
#  'badhi': 208,
#  'manche': 1334,
#  'saman': 2009,
#  'na': 1439,
#  'paisa': 1625,
#  'gari': 718,
#  'khoje': 1084,
#  'payepachi': 1651,
#  'samay': 2013,
#  'bela': 245,
#  'linu': 1278,
#  'exam': 664,
#  'haal': 788,
#  'sevaa': 2067,
#  'nyaupaane': 1566,
#  'phaarm': 1675,
#  'jggaa': 899,
#  'naammaa': 1444,
#  'gali': 695,
#  'khane': 1063,
#  'ajkal': 98,
#  'va': 2398,
#  'jastai': 891,
#  'yes': 2467,
#  'halla': 803,
#  'xan': 2451,
#  'vaya': 2408,
#  'khal': 1058,
#  'daily': 518,
#  'use': 2389,
#  'asamanta': 153,
#  'samriddhi': 2027,
#  'kami': 1008,
#  'harami': 806,
#  'cha': 425,
#  'thikai': 2243,
#  'khana': 1061,
#  'chai': 427,
#  'lgaaunu': 1268,
#  'paaniipuri': 1596,
#  'ab': 68,
#  'tehi': 2215,
#  'caak': 421,
#  'mulaahrulaai': 1426,
#  'haamro': 794,
#  'ghrmaa': 748,
#  'ttibhi': 2330,
#  'kamai': 1007,
#  'market': 1343,
#  'badhyo': 209,
#  'smcaar': 2152,
#  'ystaa': 2489,
#  'purni': 1829,
#  'nmbr': 1543,
#  'ptthaaiidinthe': 1814,
#  'naramro': 1463,
#  'khanu': 1064,
#  'masu': 1344,
#  'kelayenw': 1031,
#  'best': 251,
#  'movie': 1408,
#  'nepali': 1493,
#  'ever': 661,
#  'voli': 2429,
#  'phone': 1693,
#  'first': 678,
#  'aaj': 23,
#  'purna': 1827,
#  'sajilo': 1988,
#  'mitho': 1388,
#  'jad': 882,
#  'raksi': 1882,
#  'badhai': 202,
#  'gardai': 704,
#  'afu': 87,
#  'lagi': 1241,
#  'dekhiinchn': 561,
#  'sune': 2193,
#  'saano': 1954,
#  'tv': 2349,
#  'raajaa': 1841,
#  'badhdain': 206,
#  'samiksha': 2020,
#  'nyayik': 1568,
#  'parkash': 1637,
#  'ddelibhrii': 529,
#  'aru': 149,
#  'ruu': 1936,
#  'cij': 466,
#  'kunai': 1188,
#  'addr': 79,
#  'tthgo': 2318,
#  'tthgne': 2317,
#  'shit': 2088,
#  'ddraaibhrlaaii': 542,
#  'gaaddii': 683,
#  'jlaaiideu': 929,
#  'prakashit': 1742,
#  'ujyalo': 2367,
#  'pali': 1627,
#  'fail': 669,
#  'news': 1498,
#  'hawa': 814,
#  'jas': 889,
#  'avahelna': 164,
#  'sanrakshan': 2036,
#  'thiyn': 2247,
#  'pdddaa': 1662,
#  'visvaas': 2425,
#  'khojna': 1085,
#  'nade': 1453,
#  'aaphaimaa': 34,
#  'jun': 967,
#  'hain': 799,
#  'utpaadn': 2393,
#  'tthikai': 2321,
#  'aayo': 66,
#  'kddaa': 1024,
#  'aaun': 53,
#  'sjaay': 2126,
#  'mrtyudnndd': 1415,
#  'deshmaa': 573,
#  'bideshi': 353,
#  'rojgar': 1923,
#  'saakssii': 1945,
#  'yaar': 2463,
#  'ar': 141,
#  'khose': 1090,
#  'are': 142,
#  'raakh': 1846,
#  'dekhiyo': 565,
#  'raushan': 1892,
#  'jhaare': 903,
#  'naagriktaa': 1441,
#  'tyaagne': 2350,
#  'sbai': 2054,
#  'laag': 1204,
#  'jti': 964,
#  'sak': 1989,
#  'vanda': 2405,
#  'sanskriti': 2037,
#  'parampara': 1629,
#  'anubhav': 125,
#  'vayenw': 2412,
#  'roshni': 1929,
#  'artha': 147,
#  'prati': 1748,
#  'sikh': 2113,
#  'satya': 2050,
#  'jahi': 883,
#  'smm': 2154,
#  'pragati': 1739,
#  'yojana': 2479,
#  'badhawa': 205,
#  'dinxan': 612,
#  'samudayik': 2028,
#  'baki': 213,
#  'saanglo': 1953,
#  'boro': 400,
#  'bikas': 366,
#  'sakne': 2000,
#  'tme': 2282,
#  'matrai': 1347,
#  'nagara': 1455,
#  'muuly': 1437,
#  'ttyaablett': 2345,
#  'maatr': 1318,
#  'nimukhaahru': 1518,
#  'kaanun': 984,
#  'ris': 1912,
#  'bhram': 322,
#  'aaphai': 33,
#  'bn': 386,
#  'dimag': 604,
#  'jaanuu': 878,
#  'bic': 345,
#  'baattomaa': 191,
#  'tiin': 2263,
#  'phitt': 1687,
#  'bhnchu': 298,
#  'mnpri': 1402,
#  'saalaa': 1946,
#  'nbolaun': 1476,
#  'dimaag': 603,
#  'ystai': 2490,
#  'taatin': 2208,
#  'posstt': 1724,
#  'dekhepchi': 558,
#  'citt': 475,
#  'padha': 1612,
#  'jaanu': 877,
#  'grdai': 764,
#  'pustaamaa': 1835,
#  'laaii': 1220,
#  'dhny': 583,
#  'lastai': 1248,
#  'saflata': 1975,
#  'prerana': 1765,
#  'saathi': 1961,
#  'najikai': 1459,
#  'ghar': 740,
#  'batw': 232,
#  'bazar': 234,
#  'nagar': 1454,
#  'paaidain': 1586,
#  'mai': 1326,
#  'chutt': 463,
#  'badh': 200,
#  'basna': 228,
#  'lag': 1236,
#  'tmi': 2283,
#  'sakxau': 2003,
#  'garna': 722,
#  'lagena': 1240,
#  'project': 1796,
#  'bitaye': 378,
#  'paisaa': 1626,
#  'brbaad': 401,
#  'prkin': 1782,
#  'paahidain': 1585,
#  'ysrii': 2488,
#  'bisvs': 377,
#  'laagen': 1209,
#  'here': 825,
#  'khoj': 1083,
#  'aba': 69,
#  'niu': 1533,
#  're': 1894,
#  'maukaa': 1349,
#  'avsvaadiihruu': 167,
#  'paaunchn': 1606,
#  'paap': 1597,
#  'phrk': 1699,
#  'bjaar': 379,
#  'prhriihruu': 1771,
#  'ttraaphik': 2339,
#  'dekhinchn': 564,
#  'sonc': 2167,
#  'naagrik': 1440,
#  'uniihruu': 2377,
#  'kmaaikaa': 1138,
#  'cintit': 471,
#  'surkssaakaa': 2198,
#  'thiye': 2246,
#  'soche': 2164,
#  'khasai': 1067,
#  'pugena': 1820,
#  'tayari': 2213,
#  'sanchai': 2029,
#  'kiner': 1121,
#  'ropni': 1927,
#  'aaiyo': 22,
#  'npuger': 1552,
#  'bro': 402,
#  'xaa': 2449,
#  'dammi': 521,
#  'niddr': 1511,
#  'skssm': 2142,
#  'yogytaa': 2478,
#  'kuro': 1195,
#  'ptthaaidin': 1812,
#  'kharcha': 1066,
#  'badhaune': 204,
#  'garirahe': 719,
#  'xoro': 2459,
#  'ramesh': 1884,
#  'unc': 2373,
#  'nprnus': 1551,
#  'skne': 2140,
#  'smrthn': 2157,
#  'pchi': 1659,
#  'kaammaa': 981,
#  'nbhyaaune': 1474,
#  'sbailaaii': 2057,
#  'holaa': 843,
#  'baatt': 189,
#  'milne': 1383,
#  'tthaaun': 2314,
#  'aa': 0,
#  'des': 570,
#  'nimntrnnaa': 1516,
#  'nskne': 1558,
#  'cu': 500,
#  'milaayr': 1375,
#  'aaidinu': 19,
#  'bhyaaune': 341,
#  'miln': 1382,
#  'jasari': 890,
#  'dhanyabad': 577,
#  'kinna': 1127,
#  'yhi': 2473,
#  'sunn': 2195,
#  'baaki': 184,
#  'kukr': 1182,
#  'tero': 2217,
#  'bhrii': 327,
#  'raakhide': 1849,
#  'bihaanai': 363,
#  'ger': 738,
#  'klej': 1133,
#  'skul': 2143,
#  'bidaa': 350,
#  'aphis': 135,
#  'bholi': 319,
#  'presr': 1767,
#  'ghnttaa': 745,
#  'khuttttaa': 1112,
#  'bncro': 392,
#  'aaphnai': 37,
#  'haancn': 795,
#  'garbad': 700,
#  'xu': 2460,
#  'bata': 229,
#  'sikdai': 2112,
#  'sbkaa': 2058,
#  'sb': 2053,
#  'rogi': 1920,
#  'acet': 73,
#  'sudhar': 2183,
#  'ahi': 93,
#  'aaye': 65,
#  'laaguu': 1217,
#  'dekhaaunu': 552,
#  'yesto': 2469,
#  'boler': 398,
#  'bhnn': 308,
#  'grnupr': 782,
#  'gre': 768,
#  'himaal': 833,
#  'himaalmaa': 834,
#  'gyo': 787,
#  'saa': 1940,
#  'alchii': 99,
#  'sundar': 2191,
#  'avasar': 165,
#  'mahatwa': 1325,
#  'so': 2163,
#  'chhau': 437,
#  'sangai': 2032,
#  'ddigrii': 535,
#  'psinaa': 1807,
#  'pcaas': 1654,
#  'khaaddi': 1044,
#  'bigridain': 360,
#  'kinki': 1123,
#  'chau': 433,
#  'uslaaii': 2390,
#  'rajniti': 1878,
#  'sambhavana': 2016,
#  'abhav': 70,
#  'jstai': 961,
#  'dshai': 625,
#  'sam': 2005,
#  'dekhe': 557,
#  'esto': 657,
#  'product': 1793,
#  'thyena': 2258,
#  'preprocessing': 1764,
#  'thau': 2233,
#  'tira': 2278,
#  'ghumne': 751,
#  'safalta': 1973,
#  'proud': 1799,
#  'samaya': 2014,
#  'bujhena': 412,
#  'thaaker': 2227,
#  'aaraam': 42,
#  'speed': 2168,
#  'typing': 2356,
#  'khud': 1102,
#  'sakchhu': 1992,
#  'banchhu': 219,
#  'badal': 199,
#  'sahayogi': 1981,
#  'faida': 668,
#  'film': 676,
#  'herda': 823,
#  'jindgii': 920,
#  'chorii': 458,
#  'ssto': 2179,
#  'late': 1249,
#  'rahexau': 1869,
#  'maajh': 1304,
#  'bhaaddaa': 254,
#  'anii': 118,
#  'aaunchn': 54,
#  'muji': 1421,
#  'mnprii': 1403,
#  'laae': 1202,
#  'sphaa': 2169,
#  'paa': 1581,
#  'shr': 2094,
#  'paalo': 1593,
#  'maayaa': 1320,
#  'baau': 192,
#  'hunn': 861,
#  'ketti': 1037,
#  'dekhnai': 567,
#  'raamrii': 1854,
#  'jhijhaae': 906,
#  'laagyo': 1218,
#  'next': 1499,
#  'mah': 1322,
#  'pratibinbit': 1751,
#  'unnati': 2381,
#  'parena': 1632,
#  'ma': 1298,
#  'manai': 1333,
#  'vaihal': 2403,
#  'xitai': 2454,
#  'khatra': 1070,
#  'jati': 893,
#  'ghatera': 742,
#  'height': 816,
#  'record': 1896,
#  'garney': 725,
#  'everest': 662,
#  'bho': 317,
#  'hoin': 840,
#  'meraa': 1356,
#  'pryog': 1806,
#  'bccaahruu': 235,
#  'yslaaii': 2486,
#  'mnpraauchn': 1401,
#  'grdaichu': 765,
#  'mhsus': 1371,
#  'paanii': 1595,
#  'mausmmaa': 1351,
#  'privrtn': 1778,
#  'bigre': 359,
#  'bcpn': 238,
#  'bhnin': 307,
#  'ruttin': 1933,
#  'lekhn': 1257,
#  'baalaapn': 186,
#  'nepaalii': 1485,
#  'shbd': 2077,
#  'aaudain': 51,
#  'naam': 1443,
#  'aph': 133,
#  'spsstt': 2172,
#  'bhnyaa': 316,
#  'nsunaairaakh': 1560,
#  'kukhyaat': 1181,
#  'ddaakaahru': 525,
#  'nyaay': 1565,
#  'jb': 895,
#  'rahe': 1867,
#  'slaam': 2144,
#  'sevii': 2068,
#  'laakhau': 1224,
#  'laakh': 1223,
#  'grdaa': 763,
#  'dukhi': 635,
#  'krpyaa': 1167,
#  'hiddne': 830,
#  'khaane': 1052,
#  'khaajaa': 1047,
#  'dinchu': 606,
#  'nepaalmaa': 1490,
#  'gaahro': 685,
#  'tokin': 2287,
#  'jrivaanaa': 956,
#  'tpaaiin': 2293,
#  'ghr': 746,
#  'ghumna': 750,
#  'try': 2302,
#  'dhulo': 592,
#  'hilo': 832,
#  'bhye': 342,
#  'missing': 1387,
#  'daan': 513,
#  'dier': 601,
#  'dhnii': 582,
#  'maanche': 1308,
#  'snsaar': 2161,
#  'pauddi': 1646,
#  'sundr': 2192,
#  'kheler': 1075,
#  'priklpnaa': 1774,
#  'psinaamaa': 1808,
#  'bhbisy': 277,
#  'timrai': 2272,
#  'nischit': 1525,
#  'dukha': 634,
#  'kholau': 1086,
#  'padhne': 1617,
#  'actor': 77,
#  'karki': 1011,
#  'payo': 1652,
#  'paaye': 1609,
#  'sikna': 2117,
#  'nkcraa': 1536,
#  'jyoti': 974,
#  'jnmdin': 937,
#  'naattk': 1449,
#  'thaahaa': 2226,
#  'aamaa': 30,
#  'bll': 383,
#  'ai': 95,
#  'gardina': 709,
#  'mjaa': 1391,
#  'khosii': 1092,
#  'spn': 2170,
#  'lge': 1271,
#  'tehii': 2216,
#  'mitthaas': 1390,
#  'smjhnaa': 2153,
#  'upsthitii': 2387,
#  'chaitra': 428,
#  'paadhn': 1582,
#  'ddr': 541,
#  'aaune': 56,
#  'prlaas': 1786,
#  'holaas': 844,
#  'kmentt': 1141,
#  'troll': 2300,
#  'phndaamaa': 1690,
#  'tinihru': 2273,
#  'posttmaa': 1727,
#  'majja': 1329,
#  'gaun': 733,
#  'tyhaankaa': 2353,
#  'jntaahruu': 940,
#  'sisnu': 2122,
#  'guliyo': 785,
#  'karyakram': 1012,
#  'janta': 888,
#  'muskaan': 1432,
#  'maanchehru': 1309,
#  'jldaichn': 930,
#  'aago': 17,
#  'sahayog': 1980,
#  'anupam': 130,
#  'baba': 193,
#  'timiilaaii': 2268,
#  'grchu': 762,
#  'sakdaina': 1993,
#  'kei': 1030,
#  'sukhi': 2188,
#  'raancii': 1857,
#  'kohi': 1149,
#  'kocer': 1147,
#  'puryaaiideuu': 1831,
#  'ttrkmaa': 2340,
#  'is': 870,
#  'with': 2444,
#  'many': 1340,
#  'muslim': 1434,
#  'since': 2120,
#  'live': 1280,
#  'tolerance': 2288,
#  'and': 109,
#  'be': 243,
#  'will': 2441,
#  'there': 2236,
#  'bato': 230,
#  'bhnaulaa': 295,
#  'sng': 2159,
#  'yuvaa': 2497,
#  'watched': 2438,
#  'nhepos': 1507,
#  'ytro': 2495,
#  'netaahru': 1495,
#  'sashanik': 2045,
#  'post': 1725,
#  'service': 2065,
#  'garchu': 702,
#  'score': 2059,
#  'lgeyo': 1272,
#  'bhayo': 276,
#  'bhy': 340,
#  'kaarbaahii': 986,
#  'tthokne': 2324,
#  'sidhai': 2105,
#  'raassttrghaatii': 1860,
#  'hrulaaii': 850,
#  'belaa': 246,
#  'shi': 2081,
#  'cunaav': 501,
#  'ldddaa': 1255,
#  'milera': 1378,
#  'sakaunu': 1991,
#  'uplvdh': 2386,
#  'saamn': 1951,
#  'pti': 1810,
#  'die': 600,
#  'ruupmaa': 1938,
#  'saalo': 1947,
#  'naamsaarii': 1445,
#  'aaaaphno': 1,
#  'kokos': 1152,
#  'ttuppo': 2344,
#  'netaa': 1494,
#  'thukk': 2253,
#  'paain': 1588,
#  'yeti': 2470,
#  'thundain': 2256,
#  'jok': 951,
#  'jntaa': 939,
#  ...}

# %% [markdown]
# # N-grams

# %%
cv = CountVectorizer(ngram_range=(1,2),binary=True, max_features=5000)

# %%
X_train_bow = cv.fit_transform(X_train['Text']).toarray()
X_test_bow = cv.transform(X_test['Text']).toarray()

# %%
X_train_bow.shape
# Out:
# (3485, 5000)

# %%
print(cv.vocabulary_)
# Out:
# {'hun': 1848, 'ngrdaa': 3092, 'aphelnaa': 281, 'hun ngrdaa': 1860, 'kaarnn': 2113, 'hune': 1874, 'biplb': 723, 'jnm': 2024, 'yestai': 4938, 'hru': 1821, 'chinta': 933, 'helmett': 1727, 'pchaaddi': 3310, 'anivaary': 264, 'bsnelaaii': 834, 'gridain': 1527, 'sewa': 4209, 'swasthya': 4477, 'vridhhi': 4852, 'sewa swasthya': 4213, 'pr': 3422, 'nikai': 3109, 'lyaipuraayo': 2590, 'timii': 4587, 'bhndaa': 594, 'man': 2655, 'ananda': 236, 'man ananda': 2656, 'vyaktitwa': 4859, 'prabhavit': 3436, 'andar': 241, 'bahir': 427, 'asantushti': 317, 'garos': 1380, 'prabhavit andar': 3437, 'andar bahir': 242, 'bahir asantushti': 428, 'asantushti garos': 318, 'gardapani': 1339, 'nava': 3030, 'kasto': 2155, 'jatti': 1955, 'hainw': 1645, 'you': 4962, 'have': 1710, 'respect': 3956, 'my': 2895, 'khaau': 2204, 'kettii': 2184, 'curott': 1024, 'top': 4616, 'kettaa': 2180, 'chaadder': 900, 'tesai': 4517, 'kettii curott': 2185, 'curott top': 1026, 'maarin': 2628, 'mridain': 2841, 'ki': 2298, 'dherai': 1131, 'sab': 4039, 'saubhagya': 4182, 'gar': 1320, 'vyaktigat': 4854, 'sampannata': 4131, 'anubhoga': 271, 'gar vyaktigat': 1330, 'vyaktigat sampannata': 4857, 'paripati': 3282, 'saphalta': 4159, 'karyanvayan': 2145, 'paripati saphalta': 3283, 'saphalta karyanvayan': 4165, 'ngrii': 3093, 'thie': 4544, 'thuprai': 4573, 'mekap': 2704, 'ke': 2166, 'maadhym': 2611, 'dinu': 1197, 'jrurii': 2054, 'call': 887, 'grnu': 1572, 'thiyo': 4560, 'bhne': 599, 'ddraaun': 1074, 'video': 4825, 'thie thuprai': 4546, 'mekap ke': 2706, 'maadhym dinu': 2612, 'call grnu': 888, 'thiyo bhne': 4562, 'bhne ddraaun': 601, 'pradarshan': 3439, 'ujjwala': 4728, 'aaphain': 70, 'chu': 964, 'khushii': 2290, 'chnauttmaa': 945, 'ko': 2347, 'uddaaiidine': 4720, 'kpaal': 2363, 'pherii': 3340, 'lgaaepchi': 2546, 'ko helmett': 2348, 'pherii lgaaepchi': 3341, 'hotel': 1815, 'average': 354, 'mero': 2711, 'rahyo': 3815, 'experience': 1279, 'aaja': 42, 'bhari': 544, 'din': 1179, 'kadam': 2126, 'harek': 1665, 'rakhaula': 3837, 'aaja bhari': 43, 'bhari din': 545, 'tmro': 4608, 'afno': 179, 'kura': 2411, 'afno kura': 182, 'gte': 1591, 'vaishaakh': 4794, 'nepaal': 3051, 'aahvaan': 33, 'bnd': 789, 'maa': 2597, 'haann': 1632, 'hudain': 1845, 'haann thiyo': 1633, 'vai': 4791, 'paryo': 3291, 'mryaadit': 2849, 'bnaaunu': 783, 'mryaadit bnaaunu': 2850, 'caahi': 870, 'xaina': 4899, 'grn': 1550, 'kuraae': 2425, 'kehii': 2172, 'laayk': 2501, 'yhaan': 4945, 'grv': 1586, 'caahi xaina': 872, 'xaina grn': 4904, 'kuraae kehii': 2426, 'kehii laayk': 2173, 'pratik': 3465, 'pratibha': 3460, 'banau': 434, 'shakti': 4219, 'pratibha andar': 3461, 'gr': 1475, 'kina': 2309, 'gare': 1343, 'hatar': 1708, 'gridinu': 1530, 'srkaar': 4400, 'duii': 1230, 'kettaakettii': 2181, 'tii': 4578, 'uniihru': 4740, 'pryo': 3669, 'jnaa': 2017, 'bibaah': 670, 'bhe': 562, 'gridinu srkaar': 1531, 'uniihru pryo': 4741, 'rhnu': 3969, 'haasikhusii': 1638, 'sdhai': 4201, 'rhnu haasikhusii': 3970, 'haasikhusii sdhai': 1639, 'ge': 1404, 'thpdai': 4564, 'tthulaa': 4669, 'mhl': 2737, 'bjaarmaa': 754, 'ge thpdai': 1405, 'andhera': 247, 'nirasha': 3119, 'khushi': 2286, 'aja': 196, 'thulo': 4571, 'nagaro': 2985, 'xaina din': 4903, 'din aja': 1182, 'aja thulo': 200, 'hos': 1813, 'ruttine': 3997, 'party': 3289, 'prne': 3585, 'ghumer': 1448, 'haannu': 1634, 'laai': 2475, 'kik': 2305, 'prne ghumer': 3588, 'desh': 1111, 'chn': 940, 'bhettiinu': 574, 'challenge': 913, 'phohor': 3356, 'bhaagymaanii': 515, 'aaphno': 73, 'trash': 4630, 'aaer': 20, 'bidesh': 682, 'paae': 3203, 'kaam': 2094, 'grn phohor': 1561, 'nepaal aaphno': 3052, 'aaphno maa': 76, 'bachelor': 406, 'time': 4583, 'paxi': 3300, 'garne': 1363, 'ramailo': 3853, 'sakiyo': 4087, 'paxi garne': 3301, 'ramailo sakiyo': 3866, 'garera': 1349, 'haru': 1669, 'paaun': 3231, 'sathai': 4178, 'muskan': 2887, 'jeevan': 1961, 'garera haru': 1350, 'haru paaun': 1693, 'paaun sathai': 3234, 'muskan jeevan': 2888, 'hijo': 1768, 'ramrai': 3877, 'ramrai gayenw': 3879, 'bicraa': 677, 'garda': 1336, 'xito': 4920, 'baa': 358, ...

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score, precision_score,confusion_matrix
from sklearn.svm import SVC

# %%
gnb1 = GaussianNB()
mnb1 = MultinomialNB()
bnb1 = BernoulliNB()
gnb2 = GaussianNB()
mnb2 = MultinomialNB()
bnb2 = BernoulliNB()
svc1 = SVC(kernel='sigmoid', gamma=1.0)
svc2 = SVC(kernel='sigmoid', gamma=1.0)

# %% [markdown]
# # TFIDF

# %%
gnb1.fit(X_train_tfidf,y_train)
y_pred1 = gnb1.predict(X_test_tfidf)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.6032110091743119
# [[286  39]
#  [307 240]]
# 0.8602150537634409

# %%
mnb1.fit(X_train_tfidf,y_train)
y_pred2 = mnb1.predict(X_test_tfidf)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.7614678899082569
# [[156 169]
#  [ 39 508]]
# 0.7503692762186115

# %%
bnb1.fit(X_train_tfidf,y_train)
y_pred3 = bnb1.predict(X_test_tfidf)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.7603211009174312
# [[166 159]
#  [ 50 497]]
# 0.7576219512195121

# %%
svc1.fit(X_train_tfidf,y_train)
y_pred4 = svc1.predict(X_test_tfidf)
print(accuracy_score(y_test,y_pred4))
print(confusion_matrix(y_test,y_pred4))
print(precision_score(y_test,y_pred4))
# Out:
# 0.7557339449541285
# [[174 151]
#  [ 62 485]]
# 0.7625786163522013

# %% [markdown]
# # BOW

# %%
gnb2.fit(X_train_bow,y_train)
y_pred1 = gnb2.predict(X_test_bow)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.625
# [[278  47]
#  [280 267]]
# 0.8503184713375797

# %%
mnb2.fit(X_train_bow,y_train)
y_pred2 = mnb2.predict(X_test_bow)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.7626146788990825
# [[182 143]
#  [ 64 483]]
# 0.7715654952076677

# %%
bnb2.fit(X_train_bow,y_train)
y_pred3 = bnb2.predict(X_test_bow)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.7442660550458715
# [[141 184]
#  [ 39 508]]
# 0.7341040462427746

# %%
svc2.fit(X_train_bow,y_train)
y_pred4 = svc2.predict(X_test_bow)
print(accuracy_score(y_test,y_pred4))
print(confusion_matrix(y_test,y_pred4))
print(precision_score(y_test,y_pred4))
# Out:
# 0.6720183486238532
# [[147 178]
#  [108 439]]
# 0.7115072933549432

# %%
import pickle
pickle.dump(tfidf,open('tfidf_vectorizer.pkl','wb'))
pickle.dump(cv,open('bow_vectorizer.pkl','wb'))
pickle.dump(mnb2,open('mnb2_model.pkl','wb'))
pickle.dump(gnb2,open('gnb2_model.pkl','wb'))
pickle.dump(bnb2,open('bnb2_model.pkl','wb'))
pickle.dump(svc2,open('svc2_model.pkl','wb'))

# %%
pickle.dump(mnb1,open('mnb_model.pkl','wb'))
pickle.dump(gnb1,open('gnb_model.pkl','wb'))
pickle.dump(bnb1,open('bnb_model.pkl','wb'))
pickle.dump(svc1,open('svc_model.pkl','wb'))

# %%
__all__ = ['clean_sent']

# %%
import pickle

with open('tfidf_vectorizer.pkl', 'rb') as f:
    tfidf_vectorizer = pickle.load(f)

with open('bow_vectorizer.pkl', 'rb') as f:
    bow_vectorizer = pickle.load(f)
    
with open('mnb_model.pkl', 'rb') as f:
    mnb_model = pickle.load(f)
    
with open('gnb_model.pkl', 'rb') as f:
    gnb_model = pickle.load(f)
    
with open('bnb_model.pkl', 'rb') as f:
    bnb_model = pickle.load(f)

with open('svc_model.pkl', 'rb') as f:
    svc_model = pickle.load(f)
    
with open('svc_model.pkl', 'rb') as f:
    knc_model = pickle.load(f)

    
    

new_inputs = 'bohot harami xa'

preprocessed_inputs = clean_sent(new_inputs)

preprocessed_inputs = [preprocessed_inputs]
# Transform the preprocessed inputs using TF-IDF vectorization
tfidf_features = tfidf_vectorizer.transform(preprocessed_inputs)
tfidf_features1 = tfidf_vectorizer.transform(preprocessed_inputs).toarray()

# Predict the results
prediction_t_mnb = mnb_model.predict(tfidf_features)
prediction_t_gnb = gnb_model.predict(tfidf_features1)
prediction_t_bnb = bnb_model.predict(tfidf_features)
prediction_t_svc = svc_model.predict(tfidf_features1) 


print('prediction from mnb_model : ' ,prediction_t_mnb )
print('prediction from gnb_model : ' ,prediction_t_gnb )
print('prediction from bnb_model : ' ,prediction_t_bnb )
print('prediction from svc_model : ' ,prediction_t_svc )
# Out:
# prediction from mnb_model :  [0.]
# prediction from gnb_model :  [0.]
# prediction from bnb_model :  [0.]
# prediction from svc_model :  [0.]

# %%
with open('bow_vectorizer.pkl', 'rb') as f:
    bow_vectorizer = pickle.load(f)
    
with open('mnb2_model.pkl', 'rb') as f:
    mnb2_model = pickle.load(f)
    
with open('gnb2_model.pkl', 'rb') as f:
    gnb2_model = pickle.load(f)
    
with open('bnb2_model.pkl', 'rb') as f:
    bnb2_model = pickle.load(f)

with open('svc2_model.pkl', 'rb') as f:
    svc2_model = pickle.load(f)
    
   
    

new_inputs = 'meor tw vayana kaam aaja'

preprocessed_inputs = clean_sent(new_inputs)

preprocessed_inputs = [preprocessed_inputs]
# Transform the preprocessed inputs using TF-IDF vectorization
bow_features = bow_vectorizer.transform(preprocessed_inputs)
bow_features1 = bow_vectorizer.transform(preprocessed_inputs).toarray()

# Predict the results
prediction_b_mnb = mnb2_model.predict(bow_features)
prediction_b_gnb = gnb2_model.predict(bow_features1)
prediction_b_bnb = bnb2_model.predict(bow_features)
prediction_b_svc = svc2_model.predict(bow_features1) 


print('prediction from mnb_model : ' ,prediction_b_mnb )
print('prediction from gnb_model : ' ,prediction_b_gnb )
print('prediction from bnb_model : ' ,prediction_b_bnb )
print('prediction from svc_model : ' ,prediction_b_svc )
# Out:
# prediction from mnb_model :  [0.]
# prediction from gnb_model :  [0.]
# prediction from bnb_model :  [0.]
# prediction from svc_model :  [0.]

# %%
combined_predictions_t = np.round(np.mean([prediction_t_mnb,prediction_t_gnb,prediction_t_bnb,prediction_t_svc], axis=0))

# %%
combined_predictions_t[0]
# Out:
# 0.0

# %%
combined_predictions_b = np.round(np.mean([prediction_b_mnb,prediction_b_gnb,prediction_b_bnb,prediction_b_svc], axis=0))

# %%
combined_predictions_b[0]
# Out:
# 0.0
